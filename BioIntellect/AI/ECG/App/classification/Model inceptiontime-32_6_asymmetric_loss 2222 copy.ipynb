# %%
import gc
import tensorflow as tf
from keras import backend as K

K.clear_session()
gc.collect()

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
import ast
from pathlib import Path
import gc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras


from sklearn.metrics import f1_score, multilabel_confusion_matrix, roc_auc_score
from sklearn.preprocessing import MultiLabelBinarizer

from tensorflow.keras import mixed_precision, layers, Model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, ReLU, Add, MaxPooling1D,
    GlobalAveragePooling1D, Dense, Dropout, Concatenate
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
BASE_DIR = Path.cwd()
if not (BASE_DIR / "X_train_processed.npy").exists():
    BASE_DIR = Path(r"D:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification")

TRAIN_AUDIO_PATH = BASE_DIR / "X_train_processed.npy"
VAL_AUDIO_PATH = BASE_DIR / "X_val_processed.npy"
TEST_AUDIO_PATH = BASE_DIR / "X_test_processed.npy"

TRAIN_CSV_PATH = BASE_DIR / "ptbxl_train.csv"
VAL_CSV_PATH = BASE_DIR / "ptbxl_val.csv"
TEST_CSV_PATH = BASE_DIR / "ptbxl_test.csv"

CSV_FEATURE_COLUMNS = [
    "age",
    "sex",
    "height",
    "weight",
    "validated_by_human",
    "height_missing",
    "weight_missing",
]

EXPECTED_SIGNAL_SHAPE = (5000, 12)
BATCH_SIZE = 32
PREDICT_BATCH_SIZE = 6     
DOWNSAMPLE_STRIDE=2  
EPOCHS = 30
LEARNING_RATE = 3e-4
METRIC_THRESHOLD = 0.5
THRESHOLD_SEARCH_GRID = np.round(np.arange(0.05, 0.951, 0.01), 2)
POS_WEIGHTS_PATH = BASE_DIR / "pos_weights.npy"
USE_POS_WEIGHTS = False
POS_WEIGHTS_MAX_CAP = 10.0   

gpus = tf.config.list_physical_devices("GPU")
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass

policy_name = "mixed_float16" if gpus else "float32"
mixed_precision.set_global_policy(policy_name)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3070 Ti Laptop GPU, compute capability 8.6

# %%
def load_signal_npy(npy_path, mmap_mode="r"):
    signals = np.load(npy_path, allow_pickle=False, mmap_mode=mmap_mode)

    if signals.dtype != np.float32:
        signals = signals.astype(np.float32)

    if signals.ndim != 3 or tuple(signals.shape[1:]) != EXPECTED_SIGNAL_SHAPE:
        raise ValueError(
            f"Expected shape (N, {EXPECTED_SIGNAL_SHAPE[0]}, {EXPECTED_SIGNAL_SHAPE[1]}), got {signals.shape}"
        )

    return signals


def extract_codes_list(df):
    return df["scp_codes"].apply(lambda value: sorted(ast.literal_eval(value).keys()))


def build_feature_matrix(df, feature_cols):
    features = df[feature_cols].copy()

    bool_cols = features.select_dtypes(include=["bool"]).columns
    if len(bool_cols):
        features[bool_cols] = features[bool_cols].astype(np.float32)

    return features.astype(np.float32).to_numpy()


def assert_split_alignment(signals, features, labels, split_name):
    if len(signals) != len(features):
        raise ValueError(
            f"{split_name}: signals/features mismatch -> {len(signals)} vs {len(features)}"
        )

    if labels is not None and len(labels) != len(signals):
        raise ValueError(
            f"{split_name}: labels/signals mismatch -> {len(labels)} vs {len(signals)}"
        )

# %%
def asymmetric_loss(gamma_neg=4, gamma_pos=0, clip=0.05):
    """
    Ridnik et al. ICCV 2021
    gamma_neg=4, gamma_pos=0 هي القيم الموصى بها في الورقة
    clip=0.05 بيمنع الـ easy negatives من تخريب الـ training
    """
    def asl(y_true, y_pred):
        y_true = tf.cast(y_true, y_pred.dtype)
        
        # Asymmetric clipping
        y_pred_neg = tf.clip_by_value(y_pred + clip, 0, 1)
        
        # Probability margins
        xs_pos = y_pred
        xs_neg = 1 - y_pred_neg
        
        # Log probabilities
        los_pos = y_true * tf.math.log(tf.clip_by_value(xs_pos, 1e-7, 1))
        los_neg = (1 - y_true) * tf.math.log(tf.clip_by_value(xs_neg, 1e-7, 1))
        
        loss = los_pos + los_neg
        
        # Asymmetric focusing
        if gamma_neg > 0 or gamma_pos > 0:
            pt0 = xs_pos * y_true
            pt1 = xs_neg * (1 - y_true)
            pt = pt0 + pt1
            
            one_sided_gamma = gamma_pos * y_true + gamma_neg * (1 - y_true)
            one_sided_w = tf.pow(1 - pt, one_sided_gamma)
            loss *= one_sided_w
        
        return -tf.reduce_mean(tf.reduce_sum(loss, axis=-1))
    
    asl.__name__ = "asymmetric_loss"
    return asl

# %%
def build_multimodal_head(
    backbone,
    signal_shape,
    num_csv_features,
    num_classes,
    learning_rate=LEARNING_RATE,
    model_name="Multimodal_ECG",
):
    """
    Generic multimodal head — يشتغل مع InceptionTime أو XceptionTime.
    backbone: الموديل اللي بترجعه من build_*_backbone()
    """
    signal_input = Input(shape=signal_shape, dtype=tf.float32, name="signal_input")
    csv_input    = Input(shape=(num_csv_features,), dtype=tf.float32, name="csv_input")

    # Signal branch
    signal_features = backbone(signal_input)

    # CSV branch
    csv_x = Dense(64, activation="relu", dtype="float32", name="csv_dense1")(csv_input)
    csv_x = Dropout(0.15, name="csv_dropout1")(csv_x)
    csv_x = Dense(32, activation="relu", dtype="float32", name="csv_dense2")(csv_x)

    # Fusion
    merged = Concatenate(name="fusion")([signal_features, csv_x])

    # Classification head
    x = Dense(256, activation="relu", dtype="float32", name="head_dense1")(merged)
    x = Dropout(0.30, name="head_dropout1")(x)
    x = Dense(128, activation="relu", dtype="float32", name="head_dense2")(x)
    x = Dropout(0.20, name="head_dropout2")(x)
    output = Dense(num_classes, activation="sigmoid", dtype="float32", name="output")(x)

    model = Model(inputs=[signal_input, csv_input], outputs=output, name=model_name)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=asymmetric_loss(gamma_neg=4, gamma_pos=0, clip=0.05),        
        metrics=[
            tf.keras.metrics.AUC(name="auc_roc", multi_label=True),
            tf.keras.metrics.AUC(name="pr_auc", multi_label=True, curve="PR"),
            tf.keras.metrics.BinaryAccuracy(name="binary_accuracy"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
        ],
    )
    model.summary()
    return model

# %%
def _inception_module(x, nb_filters=32, kernel_sizes=(10, 20, 40), bottleneck_size=32, name="inception"):
    """
    القلب النابض في InceptionTime.
    
    الفكرة الأساسية: بدل ما نشوف الـ ECG بعين واحدة (kernel واحد)،
    بنشوفه بـ 4 عيون في نفس الوقت — كل عين بتشوف نطاق زمني مختلف.
    
    ليه؟ لأن الـ ECG events بيتفاوتوا في الحجم:
      - موجة P  →  صغيرة وسريعة  →  kernel صغير يمسكها
      - QRS complex  →  متوسطة  →  kernel متوسط
      - موجة T  →  كبيرة وبطيئة  →  kernel كبير
    
    الـ flow:
        x
        ├─ Bottleneck (تضغط الـ channels لتوفير VRAM)
        │   ├─ Conv(k=10)  →  branch_1
        │   ├─ Conv(k=20)  →  branch_2  
        │   └─ Conv(k=40)  →  branch_3
        └─ MaxPool(3)  →  Conv(1)  →  branch_4
        
        [branch_1, branch_2, branch_3, branch_4]
        → Concatenate → BatchNorm → ReLU → output
    """

    in_channels = x.shape[-1]  # عدد الـ channels الداخلة (مثلاً 32 أو 128)

    # ── Step 1: Bottleneck ──────────────────────────────────────────────────────
    # المشكلة: لو عندنا 128 channel وعايزين نعمل Conv(k=40) عليهم
    #          ده هيكلف VRAM كتير جداً.
    # الحل: نضغط الـ channels لـ 32 الأول بـ Conv(1×1) (مش بتغير الـ time steps)
    #       وبعدين نعمل الـ parallel convs على الـ 32 الأصغر.
    # ملحوظة: لو الـ channels أصغر من bottleneck_size أصلاً → مش محتاجين نضغط
    if bottleneck_size is not None and in_channels is not None and in_channels > bottleneck_size:
        x_bottleneck = layers.Conv1D(
            bottleneck_size,    # نضغط لـ 32 channel
            kernel_size=1,      # 1×1 conv → بس بيغير الـ channels مش الـ time
            padding='same',
            use_bias=False,     # BatchNorm جاي بعدين، الـ bias مش مفيد هنا
            name=f"{name}_bottleneck"
        )(x)
    else:
        x_bottleneck = x  # خليها زي ما هي

    # ── Step 2: Parallel Convolutions (3 branches) ─────────────────────────────
    # كل branch بيشوف نطاق زمني مختلف من الـ signal
    branches = []
    for k in kernel_sizes:  # k = 10, 20, 40
        branch = layers.Conv1D(
            nb_filters,     # 32 filter لكل branch
            kernel_size=k,  # النافذة الزمنية
            padding='same', # نحافظ على نفس عدد الـ time steps
            use_bias=False,
            name=f"{name}_conv_k{k}"
        )(x_bottleneck)
        branches.append(branch)

    # ── Step 3: MaxPool Branch ──────────────────────────────────────────────────
    # الـ branch ده مش بيتعلم — بس بياخد أقوى قيمة في كل نافذة صغيرة.
    # بيمسك الـ peaks الواضحة في الـ signal (زي الـ R peak في QRS).
    # مهم: بيشتغل على x الأصلي (مش الـ bottleneck) عشان ميخسرش معلومات.
    mp = layers.MaxPooling1D(
        pool_size=3,    # بيشوف 3 نقاط ويرجع الأكبر
        strides=1,      # بيتحرك نقطة نقطة (مش بيقلل الـ time steps)
        padding='same',
        name=f"{name}_maxpool"
    )(x)
    
    # Conv(1×1) بعد الـ MaxPool عشان يضبط عدد الـ channels زي باقي الـ branches
    mp = layers.Conv1D(
        nb_filters,
        kernel_size=1,
        padding='same',
        use_bias=False,
        name=f"{name}_mp_conv"
    )(mp)
    
    branches.append(mp)  # دلوقتي عندنا 4 branches

    # ── Step 4: Merge ───────────────────────────────────────────────────────────
    # بنجمع الـ 4 branches جنب بعض على الـ channel axis
    # لو كل branch فيه 32 channel → بعد الـ concat هيبقى 32×4 = 128 channel
    out = layers.Concatenate(name=f"{name}_concat")(branches)
    
    # BatchNorm: بينظم الـ values ويسرع الـ training
    out = layers.BatchNormalization(name=f"{name}_bn")(out)
    
    # ReLU: بيعمل non-linearity (بيحول الـ negative values لـ 0)
    out = layers.ReLU(name=f"{name}_relu")(out)
    
    return out  # shape: (batch, time_steps, 128)


def build_inceptiontime_backbone(
    input_shape=(5000, 12),   # 5 ثواني × 500Hz × 12 lead
    nb_filters=32,            # filters في كل branch داخل الـ inception
    depth=6,                  # عدد الـ inception modules (6 في البيبر الأصلي)
    kernel_sizes=(10, 20, 40),
    bottleneck_size=32,
    downsample_stride=2,      # 1 → مفيش downsample
):
    """
    الـ backbone كله — بياخد ECG signal خام ويرجع feature vector جاهز للتصنيف.
    
    الـ flow الكامل:
    
    Input (batch, 5000, 12)
         │
         ▼
    [Downsample] Conv1D(stride=1) → BN → ReLU
    (batch, 5000, 32)
         │
         ├─────────────────── residual_0 = x
         │
         ▼
    Inception_0  →  Inception_1  →  Inception_2
                                         │
                                    Add(x + shortcut)  ← Conv1D(residual_0)
                                    residual_1 = x
         │
         ▼
    Inception_3  →  Inception_4  →  Inception_5
                                         │
                                    Add(x + shortcut)  ← Conv1D(residual_1)
         │
         ▼
    GlobalAveragePooling1D
    (batch, 128)  ← feature vector جاهز
    """

    inputs = layers.Input(shape=input_shape, name="ecg_input")

    # ── Step 1: Downsampling ────────────────────────────────────────────────────
    # المشكلة: 5000 timestep كتير جداً على الـ GPU (خصوصاً مع batch_size صغير).
    # الحل: Conv1D بـ stride=5 تبقى 1000 timestep — نفس المعلومات تقريباً، VRAM أقل بكتير.
    # kernel_size = stride*2 = 10 عشان يشوف نافذة كافية قبل ما يقفز.
    if downsample_stride > 1:
        x = layers.Conv1D(
            nb_filters,
            kernel_size=downsample_stride * 2,
            strides=downsample_stride,
            padding='same',
            use_bias=False,
            name="initial_downsample"
        )(inputs)
        x = layers.BatchNormalization(name="initial_downsample_bn")(x)
        x = layers.ReLU(name="initial_downsample_relu")(x)
    else:
        x = inputs  # مفيش downsample → ابدأ من 5000 مباشرةً

    # ── Step 2: Residual Anchor ─────────────────────────────────────────────────
    # بنحفظ نسخة من x الحالي قبل ما ندخل الـ inception blocks.
    # هنستخدمها كـ "shortcut" بعد كل 3 blocks (زي ResNet).
    # الهدف: لو الـ inception blocks اتعلموا حاجة غلط → الـ gradient يعدي
    #         عن طريق الـ shortcut بدل ما يـ vanish.
    residual = x

    # عدد الـ output channels من كل inception module:
    # 3 parallel convs + 1 maxpool branch = 4 branches × 32 filter = 128
    n_out_channels = nb_filters * (len(kernel_sizes) + 1)

    # ── Step 3: Inception Blocks ────────────────────────────────────────────────
    for i in range(depth):  # i = 0, 1, 2, 3, 4, 5
        x = _inception_module(
            x,
            nb_filters=nb_filters,
            kernel_sizes=kernel_sizes,
            bottleneck_size=bottleneck_size,
            name=f"inception_{i}"
        )

        # كل 3 blocks → residual shortcut
        # i=2 → (2+1)%3 == 0 ✓  →  أول shortcut
        # i=5 → (5+1)%3 == 0 ✓  →  تاني shortcut
        if (i + 1) % 3 == 0:
            # الـ residual ممكن channels-ها تختلف عن x الحالي
            # فبنعمل Conv(1×1) عشان نوحد الـ channels قبل الـ Add
            shortcut = layers.Conv1D(
                n_out_channels,
                kernel_size=1,
                padding='same',
                use_bias=False,
                name=f"res_conv_{i}"
            )(residual)
            shortcut = layers.BatchNormalization(name=f"res_bn_{i}")(shortcut)

            # بنضيف الـ shortcut على x الحالي (مش concatenate — Add)
            x = layers.Add(name=f"res_add_{i}")([x, shortcut])
            x = layers.ReLU(name=f"res_relu_{i}")(x)

            # نحدث الـ residual للـ shortcut الجاي
            residual = x

    # ── Step 4: Global Average Pooling ─────────────────────────────────────────
    # دلوقتي x شكله (batch, 1000, 128).
    # الـ classifier مش محتاج يعرف "فين" الـ feature في الـ time axis،
    # محتاج بس "إيه" الـ features الموجودة → نعمل average على كل الـ time steps.
    # النتيجة: (batch, 128) — vector واحد يمثل الـ ECG كله.
    x = GlobalAveragePooling1D(name="gap")(x)

    return Model(inputs=inputs, outputs=x, name="InceptionTime_Backbone")

def build_multimodal_inceptiontime(
    signal_shape,
    num_csv_features,
    num_classes,
    learning_rate=LEARNING_RATE,
    nb_filters=32,
    depth=6,
    downsample_stride=DOWNSAMPLE_STRIDE,
):

    backbone = build_inceptiontime_backbone(
        input_shape=signal_shape,
        nb_filters=nb_filters,
        depth=depth,
        downsample_stride=downsample_stride,
    )

    return build_multimodal_head(
        backbone=backbone,
        signal_shape=signal_shape,
        num_csv_features=num_csv_features,
        num_classes=num_classes,
        learning_rate=learning_rate,
        model_name="Multimodal_InceptionTime",
    )

# %%
train_df = pd.read_csv(TRAIN_CSV_PATH)
val_df   = pd.read_csv(VAL_CSV_PATH)
test_df  = pd.read_csv(TEST_CSV_PATH)

# ── Balanced indices & sample weights ──────────────────────────
BALANCED_IDX_PATH    = BASE_DIR / "balanced_train_indices.npy"
SAMPLE_WEIGHTS_PATH  = BASE_DIR / "sample_weights.npy"

balanced_idx     = np.load(BALANCED_IDX_PATH)
all_weights      = np.load(SAMPLE_WEIGHTS_PATH)
train_weights    = all_weights[balanced_idx].astype(np.float32)

train_df = train_df.iloc[balanced_idx].reset_index(drop=True)

X_train_signal_full = load_signal_npy(TRAIN_AUDIO_PATH)
X_train_signal      = X_train_signal_full[balanced_idx]
del X_train_signal_full
gc.collect()

X_val_signal  = load_signal_npy(VAL_AUDIO_PATH)
X_test_signal = load_signal_npy(TEST_AUDIO_PATH)

X_train_csv = build_feature_matrix(train_df, CSV_FEATURE_COLUMNS)
X_val_csv   = build_feature_matrix(val_df,   CSV_FEATURE_COLUMNS)
X_test_csv  = build_feature_matrix(test_df,  CSV_FEATURE_COLUMNS)

mlb     = MultiLabelBinarizer()
y_train = mlb.fit_transform(extract_codes_list(train_df)).astype(np.float32)
y_val   = mlb.transform(extract_codes_list(val_df)).astype(np.float32)
y_test  = mlb.transform(extract_codes_list(test_df)).astype(np.float32)

assert_split_alignment(X_train_signal, X_train_csv, y_train, "train")
assert_split_alignment(X_val_signal,   X_val_csv,   y_val,   "val")
assert_split_alignment(X_test_signal,  X_test_csv,  y_test,  "test")

SIGNAL_SHAPE = X_train_signal.shape[1:]
NUM_CLASSES  = y_train.shape[1]

print(f"Train signal: {X_train_signal.shape}  (balanced from full set)")
print(f"Train weights: min={train_weights.min():.3f}  max={train_weights.max():.3f}")
print(f"Val signal:  {X_val_signal.shape}")
print(f"Test signal: {X_test_signal.shape}")
print(f"Num classes: {NUM_CLASSES}")
# Out:
# Train signal: (3745, 5000, 12)  (balanced from full set)
# Train weights: min=0.026  max=42.768
# Val signal:  (2183, 5000, 12)
# Test signal: (2198, 5000, 12)
# Num classes: 71

# %%
model = build_multimodal_inceptiontime(
    signal_shape=SIGNAL_SHAPE,
    num_csv_features=X_train_csv.shape[1],
    num_classes=NUM_CLASSES,
    nb_filters=32,
    depth=6,
    downsample_stride=DOWNSAMPLE_STRIDE,
)

model.summary()
# Out:
# Model: "Multimodal_InceptionTime"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  csv_input (InputLayer)         [(None, 7)]          0           []
#
#  csv_dense1 (Dense)             (None, 64)           512         ['csv_input[0][0]']
#
#  signal_input (InputLayer)      [(None, 5000, 12)]   0           []
#
#  csv_dropout1 (Dropout)         (None, 64)           0           ['csv_dense1[0][0]']
#
#  InceptionTime_Backbone (Functi  (None, 128)         498304      ['signal_input[0][0]']
#  onal)
#
#  csv_dense2 (Dense)             (None, 32)           2080        ['csv_dropout1[0][0]']
#
#  fusion (Concatenate)           (None, 160)          0           ['InceptionTime_Backbone[0][0]',
#                                                                   'csv_dense2[0][0]']
#
#  head_dense1 (Dense)            (None, 256)          41216       ['fusion[0][0]']
#
#  head_dropout1 (Dropout)        (None, 256)          0           ['head_dense1[0][0]']
#
#  head_dense2 (Dense)            (None, 128)          32896       ['head_dropout1[0][0]']
#
#  head_dropout2 (Dropout)        (None, 128)          0           ['head_dense2[0][0]']
#
#  output (Dense)                 (None, 71)           9159        ['head_dropout2[0][0]']
#
# ==================================================================================================
# Total params: 584,167
# Trainable params: 582,055
# Non-trainable params: 2,112
# __________________________________________________________________________________________________
# Model: "Multimodal_InceptionTime"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  csv_input (InputLayer)         [(None, 7)]          0           []
#
#  csv_dense1 (Dense)             (None, 64)           512         ['csv_input[0][0]']
#
#  signal_input (InputLayer)      [(None, 5000, 12)]   0           []
#
#  csv_dropout1 (Dropout)         (None, 64)           0           ['csv_dense1[0][0]']
#
#  InceptionTime_Backbone (Functi  (None, 128)         498304      ['signal_input[0][0]']
#  onal)
#
#  csv_dense2 (Dense)             (None, 32)           2080        ['csv_dropout1[0][0]']
#
#  fusion (Concatenate)           (None, 160)          0           ['InceptionTime_Backbone[0][0]',
#                                                                   'csv_dense2[0][0]']
#
#  head_dense1 (Dense)            (None, 256)          41216       ['fusion[0][0]']
#
#  head_dropout1 (Dropout)        (None, 256)          0           ['head_dense1[0][0]']
#
#  head_dense2 (Dense)            (None, 128)          32896       ['head_dropout1[0][0]']
#
#  head_dropout2 (Dropout)        (None, 128)          0           ['head_dense2[0][0]']
#
#  output (Dense)                 (None, 71)           9159        ['head_dropout2[0][0]']
#
# ==================================================================================================
# Total params: 584,167
# Trainable params: 582,055
# Non-trainable params: 2,112
# __________________________________________________________________________________________________

# %%
class MacroF1Callback(tf.keras.callbacks.Callback):
    """
    بيحسب F1 macro على الـ validation set بعد كل epoch.
    أسرع من sklearn لأنه بيشتغل بـ numpy مباشرة.
    """
    def __init__(self, val_data, threshold=0.5):
        super().__init__()
        self.X_val_signal, self.X_val_csv = val_data[0]
        self.y_val = val_data[1]
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        predictions = []
        for start in range(0, len(self.X_val_signal), PREDICT_BATCH_SIZE):
            end = min(start + PREDICT_BATCH_SIZE, len(self.X_val_signal))
            batch_pred = self.model(
                [self.X_val_signal[start:end], self.X_val_csv[start:end]],
                training=False
            ).numpy()
            predictions.append(batch_pred)
            gc.collect()
        
        y_pred = np.vstack(predictions).astype(np.float32)
        y_pred_bin = (y_pred >= self.threshold).astype(np.float32)
        y_true = self.y_val

        # F1 per class ثم average — نفس منطق sklearn
        tp = (y_true * y_pred_bin).sum(axis=0)
        fp = ((1 - y_true) * y_pred_bin).sum(axis=0)
        fn = (y_true * (1 - y_pred_bin)).sum(axis=0)

        precision = tp / np.clip(tp + fp, 1e-7, None)
        recall    = tp / np.clip(tp + fn, 1e-7, None)
        f1_per_class = 2 * precision * recall / np.clip(precision + recall, 1e-7, None)

        # نتجاهل الـ classes اللي مفيش samples منها في الـ val
        valid_mask = y_true.sum(axis=0) > 0
        f1_macro = f1_per_class[valid_mask].mean()

        logs["val_f1_macro"] = float(f1_macro)
        print(f"  — val_f1_macro: {f1_macro:.4f}")



macro_f1_cb = MacroF1Callback(
    val_data=([X_val_signal, X_val_csv], y_val),
    threshold=0.5,
)

callbacks = [
    macro_f1_cb, 

    ModelCheckpoint(
        BASE_DIR / "ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5",
        monitor="val_f1_macro",  
        mode="max",
        save_best_only=True,
        save_weights_only=False,
        verbose=1,
    ),

    EarlyStopping(
        monitor="val_f1_macro",   
        mode="max",
        patience=10,              
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_f1_macro",   
        factor=0.5,
        patience=4,               
        mode="max",
        min_lr=1e-6,           
        verbose=1,
    ),
]

# %%
history = model.fit(
    [X_train_signal, X_train_csv],
    y_train,
    validation_data=([X_val_signal, X_val_csv], y_val),
    epochs=100,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/100
# 118/118 [==============================] - ETA: 0s - loss: 4.2227 - auc_roc: 0.5330 - pr_auc: 0.0499 - binary_accuracy: 0.8957 - precision: 0.1019 - recall: 0.2095  — val_f1_macro: 0.0423
#
# Epoch 1: val_f1_macro improved from -inf to 0.04231, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 77s 567ms/step - loss: 4.2227 - auc_roc: 0.5330 - pr_auc: 0.0499 - binary_accuracy: 0.8957 - precision: 0.1019 - recall: 0.2095 - val_loss: 2.9167 - val_auc_roc: 0.7457 - val_pr_auc: 0.1209 - val_binary_accuracy: 0.9722 - val_precision: 0.7748 - val_recall: 0.4127 - val_f1_macro: 0.0423 - lr: 3.0000e-04
# Epoch 2/100
# 117/118 [============================>.] - ETA: 0s - loss: 3.2432 - auc_roc: 0.6280 - pr_auc: 0.0934 - binary_accuracy: 0.9517 - precision: 0.3591 - recall: 0.2823  — val_f1_macro: 0.0758
#
# Epoch 2: val_f1_macro improved from 0.04231 to 0.07583, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 65s 555ms/step - loss: 3.2439 - auc_roc: 0.6278 - pr_auc: 0.0934 - binary_accuracy: 0.9517 - precision: 0.3590 - recall: 0.2822 - val_loss: 2.5385 - val_auc_roc: 0.7619 - val_pr_auc: 0.1464 - val_binary_accuracy: 0.9728 - val_precision: 0.7383 - val_recall: 0.4753 - val_f1_macro: 0.0758 - lr: 3.0000e-04
# Epoch 3/100
# 117/118 [============================>.] - ETA: 0s - loss: 3.0094 - auc_roc: 0.6893 - pr_auc: 0.1280 - binary_accuracy: 0.9572 - precision: 0.4505 - recall: 0.3698  — val_f1_macro: 0.0937
#
# Epoch 3: val_f1_macro improved from 0.07583 to 0.09368, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 547ms/step - loss: 3.0095 - auc_roc: 0.6892 - pr_auc: 0.1280 - binary_accuracy: 0.9572 - precision: 0.4505 - recall: 0.3698 - val_loss: 2.4399 - val_auc_roc: 0.7864 - val_pr_auc: 0.1656 - val_binary_accuracy: 0.9722 - val_precision: 0.7021 - val_recall: 0.5048 - val_f1_macro: 0.0937 - lr: 3.0000e-04
# Epoch 4/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.8630 - auc_roc: 0.7232 - pr_auc: 0.1518 - binary_accuracy: 0.9593 - precision: 0.4826 - recall: 0.4202  — val_f1_macro: 0.1238
#
# Epoch 4: val_f1_macro improved from 0.09368 to 0.12379, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 543ms/step - loss: 2.8640 - auc_roc: 0.7231 - pr_auc: 0.1518 - binary_accuracy: 0.9593 - precision: 0.4826 - recall: 0.4200 - val_loss: 2.4826 - val_auc_roc: 0.7890 - val_pr_auc: 0.1850 - val_binary_accuracy: 0.9711 - val_precision: 0.6635 - val_recall: 0.5365 - val_f1_macro: 0.1238 - lr: 3.0000e-04
# Epoch 5/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.7965 - auc_roc: 0.7457 - pr_auc: 0.1628 - binary_accuracy: 0.9607 - precision: 0.5028 - recall: 0.4424  — val_f1_macro: 0.1296
#
# Epoch 5: val_f1_macro improved from 0.12379 to 0.12962, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 543ms/step - loss: 2.7967 - auc_roc: 0.7456 - pr_auc: 0.1628 - binary_accuracy: 0.9606 - precision: 0.5028 - recall: 0.4423 - val_loss: 2.4146 - val_auc_roc: 0.8044 - val_pr_auc: 0.1910 - val_binary_accuracy: 0.9717 - val_precision: 0.6659 - val_recall: 0.5585 - val_f1_macro: 0.1296 - lr: 3.0000e-04
# Epoch 6/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.6979 - auc_roc: 0.7858 - pr_auc: 0.1787 - binary_accuracy: 0.9620 - precision: 0.5226 - recall: 0.4680  — val_f1_macro: 0.1447
#
# Epoch 6: val_f1_macro improved from 0.12962 to 0.14473, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 547ms/step - loss: 2.6976 - auc_roc: 0.7858 - pr_auc: 0.1786 - binary_accuracy: 0.9620 - precision: 0.5225 - recall: 0.4680 - val_loss: 2.4157 - val_auc_roc: 0.8150 - val_pr_auc: 0.2019 - val_binary_accuracy: 0.9719 - val_precision: 0.6722 - val_recall: 0.5564 - val_f1_macro: 0.1447 - lr: 3.0000e-04
# Epoch 7/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.6171 - auc_roc: 0.7938 - pr_auc: 0.1960 - binary_accuracy: 0.9625 - precision: 0.5278 - recall: 0.4957  — val_f1_macro: 0.1451
#
# Epoch 7: val_f1_macro improved from 0.14473 to 0.14510, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 545ms/step - loss: 2.6173 - auc_roc: 0.7938 - pr_auc: 0.1960 - binary_accuracy: 0.9625 - precision: 0.5278 - recall: 0.4957 - val_loss: 2.3674 - val_auc_roc: 0.8182 - val_pr_auc: 0.2141 - val_binary_accuracy: 0.9727 - val_precision: 0.6788 - val_recall: 0.5779 - val_f1_macro: 0.1451 - lr: 3.0000e-04
# Epoch 8/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.5939 - auc_roc: 0.8011 - pr_auc: 0.2060 - binary_accuracy: 0.9632 - precision: 0.5364 - recall: 0.5085  — val_f1_macro: 0.1564
#
# Epoch 8: val_f1_macro improved from 0.14510 to 0.15640, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 543ms/step - loss: 2.5939 - auc_roc: 0.8014 - pr_auc: 0.2060 - binary_accuracy: 0.9632 - precision: 0.5364 - recall: 0.5085 - val_loss: 2.2483 - val_auc_roc: 0.8287 - val_pr_auc: 0.2141 - val_binary_accuracy: 0.9731 - val_precision: 0.6758 - val_recall: 0.6029 - val_f1_macro: 0.1564 - lr: 3.0000e-04
# Epoch 9/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.5415 - auc_roc: 0.8084 - pr_auc: 0.2145 - binary_accuracy: 0.9638 - precision: 0.5442 - recall: 0.5196  — val_f1_macro: 0.1802
#
# Epoch 9: val_f1_macro improved from 0.15640 to 0.18016, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 546ms/step - loss: 2.5416 - auc_roc: 0.8083 - pr_auc: 0.2145 - binary_accuracy: 0.9638 - precision: 0.5442 - recall: 0.5194 - val_loss: 2.2195 - val_auc_roc: 0.8463 - val_pr_auc: 0.2305 - val_binary_accuracy: 0.9722 - val_precision: 0.6480 - val_recall: 0.6394 - val_f1_macro: 0.1802 - lr: 3.0000e-04
# Epoch 10/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.5092 - auc_roc: 0.8260 - pr_auc: 0.2193 - binary_accuracy: 0.9640 - precision: 0.5457 - recall: 0.5328  — val_f1_macro: 0.1650
#
# Epoch 10: val_f1_macro did not improve from 0.18016
# 118/118 [==============================] - 63s 534ms/step - loss: 2.5109 - auc_roc: 0.8260 - pr_auc: 0.2193 - binary_accuracy: 0.9640 - precision: 0.5455 - recall: 0.5324 - val_loss: 2.4744 - val_auc_roc: 0.8173 - val_pr_auc: 0.2161 - val_binary_accuracy: 0.9683 - val_precision: 0.5978 - val_recall: 0.5886 - val_f1_macro: 0.1650 - lr: 3.0000e-04
# Epoch 11/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.4722 - auc_roc: 0.8286 - pr_auc: 0.2298 - binary_accuracy: 0.9643 - precision: 0.5486 - recall: 0.5429  — val_f1_macro: 0.1712
#
# Epoch 11: val_f1_macro did not improve from 0.18016
# 118/118 [==============================] - 64s 546ms/step - loss: 2.4720 - auc_roc: 0.8286 - pr_auc: 0.2298 - binary_accuracy: 0.9643 - precision: 0.5485 - recall: 0.5428 - val_loss: 2.2695 - val_auc_roc: 0.8482 - val_pr_auc: 0.2283 - val_binary_accuracy: 0.9738 - val_precision: 0.6906 - val_recall: 0.6012 - val_f1_macro: 0.1712 - lr: 3.0000e-04
# Epoch 12/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.4198 - auc_roc: 0.8429 - pr_auc: 0.2440 - binary_accuracy: 0.9657 - precision: 0.5680 - recall: 0.5584  — val_f1_macro: 0.1924
#
# Epoch 12: val_f1_macro improved from 0.18016 to 0.19237, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 542ms/step - loss: 2.4204 - auc_roc: 0.8428 - pr_auc: 0.2440 - binary_accuracy: 0.9657 - precision: 0.5679 - recall: 0.5582 - val_loss: 2.1884 - val_auc_roc: 0.8431 - val_pr_auc: 0.2431 - val_binary_accuracy: 0.9743 - val_precision: 0.6930 - val_recall: 0.6220 - val_f1_macro: 0.1924 - lr: 3.0000e-04
# Epoch 13/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.4184 - auc_roc: 0.8439 - pr_auc: 0.2443 - binary_accuracy: 0.9654 - precision: 0.5642 - recall: 0.5539  — val_f1_macro: 0.1730
#
# Epoch 13: val_f1_macro did not improve from 0.19237
# 118/118 [==============================] - 64s 540ms/step - loss: 2.4187 - auc_roc: 0.8438 - pr_auc: 0.2443 - binary_accuracy: 0.9654 - precision: 0.5641 - recall: 0.5539 - val_loss: 2.2645 - val_auc_roc: 0.8513 - val_pr_auc: 0.2355 - val_binary_accuracy: 0.9732 - val_precision: 0.6742 - val_recall: 0.6147 - val_f1_macro: 0.1730 - lr: 3.0000e-04
# Epoch 14/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.3773 - auc_roc: 0.8546 - pr_auc: 0.2550 - binary_accuracy: 0.9664 - precision: 0.5762 - recall: 0.5670  — val_f1_macro: 0.1860
#
# Epoch 14: val_f1_macro did not improve from 0.19237
# 118/118 [==============================] - 63s 538ms/step - loss: 2.3778 - auc_roc: 0.8545 - pr_auc: 0.2549 - binary_accuracy: 0.9664 - precision: 0.5762 - recall: 0.5668 - val_loss: 2.1674 - val_auc_roc: 0.8479 - val_pr_auc: 0.2498 - val_binary_accuracy: 0.9735 - val_precision: 0.6706 - val_recall: 0.6374 - val_f1_macro: 0.1860 - lr: 3.0000e-04
# Epoch 15/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.4109 - auc_roc: 0.8540 - pr_auc: 0.2572 - binary_accuracy: 0.9658 - precision: 0.5683 - recall: 0.5577  — val_f1_macro: 0.1907
#
# Epoch 15: val_f1_macro did not improve from 0.19237
# 118/118 [==============================] - 63s 538ms/step - loss: 2.4110 - auc_roc: 0.8539 - pr_auc: 0.2572 - binary_accuracy: 0.9657 - precision: 0.5682 - recall: 0.5577 - val_loss: 2.2688 - val_auc_roc: 0.8467 - val_pr_auc: 0.2378 - val_binary_accuracy: 0.9731 - val_precision: 0.6753 - val_recall: 0.6037 - val_f1_macro: 0.1907 - lr: 3.0000e-04
# Epoch 16/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.3580 - auc_roc: 0.8572 - pr_auc: 0.2608 - binary_accuracy: 0.9664 - precision: 0.5751 - recall: 0.5725  — val_f1_macro: 0.1849
#
# Epoch 16: val_f1_macro did not improve from 0.19237
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 118/118 [==============================] - 63s 534ms/step - loss: 2.3581 - auc_roc: 0.8571 - pr_auc: 0.2607 - binary_accuracy: 0.9664 - precision: 0.5751 - recall: 0.5725 - val_loss: 2.3468 - val_auc_roc: 0.8356 - val_pr_auc: 0.2248 - val_binary_accuracy: 0.9696 - val_precision: 0.6075 - val_recall: 0.6374 - val_f1_macro: 0.1849 - lr: 3.0000e-04
# Epoch 17/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.2662 - auc_roc: 0.8768 - pr_auc: 0.2840 - binary_accuracy: 0.9678 - precision: 0.5928 - recall: 0.5951  — val_f1_macro: 0.1864
#
# Epoch 17: val_f1_macro did not improve from 0.19237
# 118/118 [==============================] - 64s 542ms/step - loss: 2.2671 - auc_roc: 0.8769 - pr_auc: 0.2840 - binary_accuracy: 0.9678 - precision: 0.5927 - recall: 0.5950 - val_loss: 2.2571 - val_auc_roc: 0.8615 - val_pr_auc: 0.2465 - val_binary_accuracy: 0.9720 - val_precision: 0.6573 - val_recall: 0.6011 - val_f1_macro: 0.1864 - lr: 1.5000e-04
# Epoch 18/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.2203 - auc_roc: 0.8803 - pr_auc: 0.2902 - binary_accuracy: 0.9684 - precision: 0.5999 - recall: 0.6070  — val_f1_macro: 0.2023
#
# Epoch 18: val_f1_macro improved from 0.19237 to 0.20233, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 543ms/step - loss: 2.2204 - auc_roc: 0.8802 - pr_auc: 0.2902 - binary_accuracy: 0.9684 - precision: 0.5999 - recall: 0.6068 - val_loss: 2.2090 - val_auc_roc: 0.8641 - val_pr_auc: 0.2527 - val_binary_accuracy: 0.9736 - val_precision: 0.6770 - val_recall: 0.6261 - val_f1_macro: 0.2023 - lr: 1.5000e-04
# Epoch 19/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.2030 - auc_roc: 0.8826 - pr_auc: 0.2896 - binary_accuracy: 0.9686 - precision: 0.6004 - recall: 0.6126  — val_f1_macro: 0.2054
#
# Epoch 19: val_f1_macro improved from 0.20233 to 0.20539, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 63s 533ms/step - loss: 2.2044 - auc_roc: 0.8825 - pr_auc: 0.2896 - binary_accuracy: 0.9685 - precision: 0.6003 - recall: 0.6123 - val_loss: 2.1614 - val_auc_roc: 0.8651 - val_pr_auc: 0.2598 - val_binary_accuracy: 0.9731 - val_precision: 0.6559 - val_recall: 0.6616 - val_f1_macro: 0.2054 - lr: 1.5000e-04
# Epoch 20/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.1769 - auc_roc: 0.8896 - pr_auc: 0.3001 - binary_accuracy: 0.9690 - precision: 0.6050 - recall: 0.6235  — val_f1_macro: 0.1853
#
# Epoch 20: val_f1_macro did not improve from 0.20539
# 118/118 [==============================] - 63s 540ms/step - loss: 2.1772 - auc_roc: 0.8895 - pr_auc: 0.3000 - binary_accuracy: 0.9690 - precision: 0.6048 - recall: 0.6234 - val_loss: 2.2457 - val_auc_roc: 0.8638 - val_pr_auc: 0.2439 - val_binary_accuracy: 0.9738 - val_precision: 0.6910 - val_recall: 0.6021 - val_f1_macro: 0.1853 - lr: 1.5000e-04
# Epoch 21/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.1493 - auc_roc: 0.8884 - pr_auc: 0.3061 - binary_accuracy: 0.9693 - precision: 0.6110 - recall: 0.6189  — val_f1_macro: 0.2030
#
# Epoch 21: val_f1_macro did not improve from 0.20539
# 118/118 [==============================] - 64s 545ms/step - loss: 2.1496 - auc_roc: 0.8883 - pr_auc: 0.3060 - binary_accuracy: 0.9693 - precision: 0.6109 - recall: 0.6188 - val_loss: 2.2595 - val_auc_roc: 0.8559 - val_pr_auc: 0.2553 - val_binary_accuracy: 0.9717 - val_precision: 0.6453 - val_recall: 0.6172 - val_f1_macro: 0.2030 - lr: 1.5000e-04
# Epoch 22/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.1436 - auc_roc: 0.8983 - pr_auc: 0.3127 - binary_accuracy: 0.9694 - precision: 0.6101 - recall: 0.6237  — val_f1_macro: 0.2071
#
# Epoch 22: val_f1_macro improved from 0.20539 to 0.20715, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 62s 528ms/step - loss: 2.1445 - auc_roc: 0.8985 - pr_auc: 0.3126 - binary_accuracy: 0.9694 - precision: 0.6101 - recall: 0.6235 - val_loss: 2.2032 - val_auc_roc: 0.8592 - val_pr_auc: 0.2491 - val_binary_accuracy: 0.9724 - val_precision: 0.6514 - val_recall: 0.6374 - val_f1_macro: 0.2071 - lr: 1.5000e-04
# Epoch 23/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.1172 - auc_roc: 0.8944 - pr_auc: 0.3150 - binary_accuracy: 0.9700 - precision: 0.6173 - recall: 0.6323  — val_f1_macro: 0.1977
#
# Epoch 23: val_f1_macro did not improve from 0.20715
# 118/118 [==============================] - 63s 537ms/step - loss: 2.1177 - auc_roc: 0.8944 - pr_auc: 0.3149 - binary_accuracy: 0.9700 - precision: 0.6174 - recall: 0.6322 - val_loss: 2.4454 - val_auc_roc: 0.8455 - val_pr_auc: 0.2500 - val_binary_accuracy: 0.9702 - val_precision: 0.6308 - val_recall: 0.5812 - val_f1_macro: 0.1977 - lr: 1.5000e-04
# Epoch 24/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.1069 - auc_roc: 0.9007 - pr_auc: 0.3184 - binary_accuracy: 0.9700 - precision: 0.6169 - recall: 0.6366  — val_f1_macro: 0.2117
#
# Epoch 24: val_f1_macro improved from 0.20715 to 0.21166, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 544ms/step - loss: 2.1069 - auc_roc: 0.9006 - pr_auc: 0.3183 - binary_accuracy: 0.9700 - precision: 0.6169 - recall: 0.6365 - val_loss: 2.2903 - val_auc_roc: 0.8601 - val_pr_auc: 0.2566 - val_binary_accuracy: 0.9715 - val_precision: 0.6419 - val_recall: 0.6182 - val_f1_macro: 0.2117 - lr: 1.5000e-04
# Epoch 25/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.0745 - auc_roc: 0.9032 - pr_auc: 0.3177 - binary_accuracy: 0.9705 - precision: 0.6238 - recall: 0.6412  — val_f1_macro: 0.2084
#
# Epoch 25: val_f1_macro did not improve from 0.21166
# 118/118 [==============================] - 64s 543ms/step - loss: 2.0746 - auc_roc: 0.9031 - pr_auc: 0.3177 - binary_accuracy: 0.9705 - precision: 0.6238 - recall: 0.6411 - val_loss: 2.2946 - val_auc_roc: 0.8622 - val_pr_auc: 0.2429 - val_binary_accuracy: 0.9730 - val_precision: 0.6695 - val_recall: 0.6162 - val_f1_macro: 0.2084 - lr: 1.5000e-04
# Epoch 26/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.0867 - auc_roc: 0.9031 - pr_auc: 0.3210 - binary_accuracy: 0.9703 - precision: 0.6202 - recall: 0.6404  — val_f1_macro: 0.2072
#
# Epoch 26: val_f1_macro did not improve from 0.21166
# 118/118 [==============================] - 63s 540ms/step - loss: 2.0880 - auc_roc: 0.9030 - pr_auc: 0.3208 - binary_accuracy: 0.9703 - precision: 0.6201 - recall: 0.6401 - val_loss: 2.3274 - val_auc_roc: 0.8603 - val_pr_auc: 0.2487 - val_binary_accuracy: 0.9718 - val_precision: 0.6465 - val_recall: 0.6229 - val_f1_macro: 0.2072 - lr: 1.5000e-04
# Epoch 27/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.0603 - auc_roc: 0.9033 - pr_auc: 0.3237 - binary_accuracy: 0.9710 - precision: 0.6292 - recall: 0.6464  — val_f1_macro: 0.2166
#
# Epoch 27: val_f1_macro improved from 0.21166 to 0.21659, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 63s 540ms/step - loss: 2.0606 - auc_roc: 0.9032 - pr_auc: 0.3236 - binary_accuracy: 0.9709 - precision: 0.6291 - recall: 0.6463 - val_loss: 2.2119 - val_auc_roc: 0.8652 - val_pr_auc: 0.2551 - val_binary_accuracy: 0.9731 - val_precision: 0.6549 - val_recall: 0.6652 - val_f1_macro: 0.2166 - lr: 1.5000e-04
# Epoch 28/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.0331 - auc_roc: 0.9058 - pr_auc: 0.3361 - binary_accuracy: 0.9709 - precision: 0.6267 - recall: 0.6507  — val_f1_macro: 0.2135
#
# Epoch 28: val_f1_macro did not improve from 0.21659
# 118/118 [==============================] - 64s 542ms/step - loss: 2.0338 - auc_roc: 0.9058 - pr_auc: 0.3360 - binary_accuracy: 0.9709 - precision: 0.6267 - recall: 0.6504 - val_loss: 2.3502 - val_auc_roc: 0.8477 - val_pr_auc: 0.2505 - val_binary_accuracy: 0.9704 - val_precision: 0.6231 - val_recall: 0.6213 - val_f1_macro: 0.2135 - lr: 1.5000e-04
# Epoch 29/100
# 117/118 [============================>.] - ETA: 0s - loss: 2.0276 - auc_roc: 0.9083 - pr_auc: 0.3310 - binary_accuracy: 0.9708 - precision: 0.6253 - recall: 0.6521  — val_f1_macro: 0.2116
#
# Epoch 29: val_f1_macro did not improve from 0.21659
# 118/118 [==============================] - 63s 533ms/step - loss: 2.0280 - auc_roc: 0.9082 - pr_auc: 0.3309 - binary_accuracy: 0.9708 - precision: 0.6251 - recall: 0.6520 - val_loss: 2.3282 - val_auc_roc: 0.8634 - val_pr_auc: 0.2478 - val_binary_accuracy: 0.9723 - val_precision: 0.6537 - val_recall: 0.6238 - val_f1_macro: 0.2116 - lr: 1.5000e-04
# Epoch 30/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9951 - auc_roc: 0.9147 - pr_auc: 0.3335 - binary_accuracy: 0.9713 - precision: 0.6324 - recall: 0.6552  — val_f1_macro: 0.2109
#
# Epoch 30: val_f1_macro did not improve from 0.21659
# 118/118 [==============================] - 64s 548ms/step - loss: 1.9951 - auc_roc: 0.9146 - pr_auc: 0.3335 - binary_accuracy: 0.9713 - precision: 0.6323 - recall: 0.6552 - val_loss: 2.2710 - val_auc_roc: 0.8619 - val_pr_auc: 0.2595 - val_binary_accuracy: 0.9738 - val_precision: 0.6778 - val_recall: 0.6321 - val_f1_macro: 0.2109 - lr: 1.5000e-04
# Epoch 31/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9756 - auc_roc: 0.9145 - pr_auc: 0.3413 - binary_accuracy: 0.9721 - precision: 0.6431 - recall: 0.6607  — val_f1_macro: 0.2188
#
# Epoch 31: val_f1_macro improved from 0.21659 to 0.21878, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 545ms/step - loss: 1.9760 - auc_roc: 0.9147 - pr_auc: 0.3413 - binary_accuracy: 0.9721 - precision: 0.6431 - recall: 0.6605 - val_loss: 2.3511 - val_auc_roc: 0.8501 - val_pr_auc: 0.2556 - val_binary_accuracy: 0.9707 - val_precision: 0.6186 - val_recall: 0.6632 - val_f1_macro: 0.2188 - lr: 1.5000e-04
# Epoch 32/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9669 - auc_roc: 0.9182 - pr_auc: 0.3480 - binary_accuracy: 0.9716 - precision: 0.6335 - recall: 0.6664  — val_f1_macro: 0.2086
#
# Epoch 32: val_f1_macro did not improve from 0.21878
# 118/118 [==============================] - 64s 544ms/step - loss: 1.9669 - auc_roc: 0.9181 - pr_auc: 0.3480 - binary_accuracy: 0.9716 - precision: 0.6334 - recall: 0.6664 - val_loss: 2.3155 - val_auc_roc: 0.8655 - val_pr_auc: 0.2522 - val_binary_accuracy: 0.9731 - val_precision: 0.6724 - val_recall: 0.6147 - val_f1_macro: 0.2086 - lr: 1.5000e-04
# Epoch 33/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9555 - auc_roc: 0.9180 - pr_auc: 0.3452 - binary_accuracy: 0.9718 - precision: 0.6392 - recall: 0.6604  — val_f1_macro: 0.2028
#
# Epoch 33: val_f1_macro did not improve from 0.21878
# 118/118 [==============================] - 65s 553ms/step - loss: 1.9561 - auc_roc: 0.9179 - pr_auc: 0.3450 - binary_accuracy: 0.9718 - precision: 0.6390 - recall: 0.6603 - val_loss: 2.5489 - val_auc_roc: 0.8480 - val_pr_auc: 0.2485 - val_binary_accuracy: 0.9697 - val_precision: 0.6179 - val_recall: 0.5999 - val_f1_macro: 0.2028 - lr: 1.5000e-04
# Epoch 34/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9448 - auc_roc: 0.9144 - pr_auc: 0.3471 - binary_accuracy: 0.9721 - precision: 0.6423 - recall: 0.6657  — val_f1_macro: 0.2090
#
# Epoch 34: val_f1_macro did not improve from 0.21878
# 118/118 [==============================] - 65s 552ms/step - loss: 1.9452 - auc_roc: 0.9144 - pr_auc: 0.3471 - binary_accuracy: 0.9721 - precision: 0.6422 - recall: 0.6655 - val_loss: 2.3997 - val_auc_roc: 0.8527 - val_pr_auc: 0.2554 - val_binary_accuracy: 0.9736 - val_precision: 0.6810 - val_recall: 0.6162 - val_f1_macro: 0.2090 - lr: 1.5000e-04
# Epoch 35/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.9190 - auc_roc: 0.9230 - pr_auc: 0.3604 - binary_accuracy: 0.9725 - precision: 0.6468 - recall: 0.6726  — val_f1_macro: 0.2140
#
# Epoch 35: val_f1_macro did not improve from 0.21878
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 118/118 [==============================] - 66s 565ms/step - loss: 1.9197 - auc_roc: 0.9230 - pr_auc: 0.3602 - binary_accuracy: 0.9725 - precision: 0.6465 - recall: 0.6724 - val_loss: 2.4014 - val_auc_roc: 0.8628 - val_pr_auc: 0.2618 - val_binary_accuracy: 0.9726 - val_precision: 0.6561 - val_recall: 0.6338 - val_f1_macro: 0.2140 - lr: 1.5000e-04
# Epoch 36/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.8672 - auc_roc: 0.9274 - pr_auc: 0.3687 - binary_accuracy: 0.9731 - precision: 0.6526 - recall: 0.6814  — val_f1_macro: 0.2203
#
# Epoch 36: val_f1_macro improved from 0.21878 to 0.22026, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 67s 567ms/step - loss: 1.8675 - auc_roc: 0.9274 - pr_auc: 0.3686 - binary_accuracy: 0.9730 - precision: 0.6525 - recall: 0.6813 - val_loss: 2.3088 - val_auc_roc: 0.8630 - val_pr_auc: 0.2577 - val_binary_accuracy: 0.9724 - val_precision: 0.6583 - val_recall: 0.6182 - val_f1_macro: 0.2203 - lr: 7.5000e-05
# Epoch 37/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.8304 - auc_roc: 0.9260 - pr_auc: 0.3716 - binary_accuracy: 0.9736 - precision: 0.6585 - recall: 0.6916  — val_f1_macro: 0.2236
#
# Epoch 37: val_f1_macro improved from 0.22026 to 0.22361, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 64s 543ms/step - loss: 1.8306 - auc_roc: 0.9259 - pr_auc: 0.3715 - binary_accuracy: 0.9736 - precision: 0.6585 - recall: 0.6916 - val_loss: 2.3377 - val_auc_roc: 0.8447 - val_pr_auc: 0.2585 - val_binary_accuracy: 0.9715 - val_precision: 0.6358 - val_recall: 0.6437 - val_f1_macro: 0.2236 - lr: 7.5000e-05
# Epoch 38/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.8342 - auc_roc: 0.9286 - pr_auc: 0.3661 - binary_accuracy: 0.9737 - precision: 0.6595 - recall: 0.6905  — val_f1_macro: 0.2254
#
# Epoch 38: val_f1_macro improved from 0.22361 to 0.22539, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 74s 633ms/step - loss: 1.8342 - auc_roc: 0.9286 - pr_auc: 0.3660 - binary_accuracy: 0.9737 - precision: 0.6595 - recall: 0.6904 - val_loss: 2.3475 - val_auc_roc: 0.8577 - val_pr_auc: 0.2601 - val_binary_accuracy: 0.9719 - val_precision: 0.6413 - val_recall: 0.6451 - val_f1_macro: 0.2254 - lr: 7.5000e-05
# Epoch 39/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.8073 - auc_roc: 0.9328 - pr_auc: 0.3769 - binary_accuracy: 0.9739 - precision: 0.6630 - recall: 0.6922  — val_f1_macro: 0.2168
#
# Epoch 39: val_f1_macro did not improve from 0.22539
# 118/118 [==============================] - 80s 677ms/step - loss: 1.8073 - auc_roc: 0.9328 - pr_auc: 0.3769 - binary_accuracy: 0.9739 - precision: 0.6628 - recall: 0.6922 - val_loss: 2.5112 - val_auc_roc: 0.8571 - val_pr_auc: 0.2653 - val_binary_accuracy: 0.9709 - val_precision: 0.6338 - val_recall: 0.6103 - val_f1_macro: 0.2168 - lr: 7.5000e-05
# Epoch 40/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7963 - auc_roc: 0.9315 - pr_auc: 0.3744 - binary_accuracy: 0.9743 - precision: 0.6670 - recall: 0.6982  — val_f1_macro: 0.2176
#
# Epoch 40: val_f1_macro did not improve from 0.22539
# 118/118 [==============================] - 79s 674ms/step - loss: 1.7968 - auc_roc: 0.9315 - pr_auc: 0.3742 - binary_accuracy: 0.9743 - precision: 0.6668 - recall: 0.6981 - val_loss: 2.4500 - val_auc_roc: 0.8597 - val_pr_auc: 0.2591 - val_binary_accuracy: 0.9724 - val_precision: 0.6621 - val_recall: 0.6077 - val_f1_macro: 0.2176 - lr: 7.5000e-05
# Epoch 41/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7798 - auc_roc: 0.9334 - pr_auc: 0.3817 - binary_accuracy: 0.9742 - precision: 0.6626 - recall: 0.7060  — val_f1_macro: 0.2339
#
# Epoch 41: val_f1_macro improved from 0.22539 to 0.23390, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_loss-min_best_balance.h5
# 118/118 [==============================] - 80s 680ms/step - loss: 1.7799 - auc_roc: 0.9334 - pr_auc: 0.3817 - binary_accuracy: 0.9742 - precision: 0.6626 - recall: 0.7058 - val_loss: 2.4054 - val_auc_roc: 0.8560 - val_pr_auc: 0.2738 - val_binary_accuracy: 0.9720 - val_precision: 0.6394 - val_recall: 0.6589 - val_f1_macro: 0.2339 - lr: 7.5000e-05
# Epoch 42/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7730 - auc_roc: 0.9308 - pr_auc: 0.3809 - binary_accuracy: 0.9741 - precision: 0.6624 - recall: 0.7056  — val_f1_macro: 0.2247
#
# Epoch 42: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 81s 690ms/step - loss: 1.7734 - auc_roc: 0.9307 - pr_auc: 0.3809 - binary_accuracy: 0.9741 - precision: 0.6624 - recall: 0.7055 - val_loss: 2.4890 - val_auc_roc: 0.8530 - val_pr_auc: 0.2590 - val_binary_accuracy: 0.9717 - val_precision: 0.6396 - val_recall: 0.6389 - val_f1_macro: 0.2247 - lr: 7.5000e-05
# Epoch 43/100
# 118/118 [==============================] - ETA: 0s - loss: 1.7599 - auc_roc: 0.9305 - pr_auc: 0.3870 - binary_accuracy: 0.9741 - precision: 0.6621 - recall: 0.7058  — val_f1_macro: 0.2273
#
# Epoch 43: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 80s 680ms/step - loss: 1.7599 - auc_roc: 0.9305 - pr_auc: 0.3870 - binary_accuracy: 0.9741 - precision: 0.6621 - recall: 0.7058 - val_loss: 2.5292 - val_auc_roc: 0.8590 - val_pr_auc: 0.2691 - val_binary_accuracy: 0.9718 - val_precision: 0.6433 - val_recall: 0.6325 - val_f1_macro: 0.2273 - lr: 7.5000e-05
# Epoch 44/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7459 - auc_roc: 0.9367 - pr_auc: 0.3965 - binary_accuracy: 0.9746 - precision: 0.6694 - recall: 0.7078  — val_f1_macro: 0.2210
#
# Epoch 44: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 79s 674ms/step - loss: 1.7458 - auc_roc: 0.9367 - pr_auc: 0.3964 - binary_accuracy: 0.9746 - precision: 0.6692 - recall: 0.7078 - val_loss: 2.6891 - val_auc_roc: 0.8585 - val_pr_auc: 0.2584 - val_binary_accuracy: 0.9704 - val_precision: 0.6198 - val_recall: 0.6387 - val_f1_macro: 0.2210 - lr: 7.5000e-05
# Epoch 45/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7638 - auc_roc: 0.9331 - pr_auc: 0.3867 - binary_accuracy: 0.9746 - precision: 0.6694 - recall: 0.7056  — val_f1_macro: 0.2223
#
# Epoch 45: val_f1_macro did not improve from 0.23390
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 118/118 [==============================] - 81s 688ms/step - loss: 1.7640 - auc_roc: 0.9331 - pr_auc: 0.3867 - binary_accuracy: 0.9746 - precision: 0.6694 - recall: 0.7055 - val_loss: 2.5253 - val_auc_roc: 0.8601 - val_pr_auc: 0.2595 - val_binary_accuracy: 0.9710 - val_precision: 0.6337 - val_recall: 0.6206 - val_f1_macro: 0.2223 - lr: 7.5000e-05
# Epoch 46/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7130 - auc_roc: 0.9386 - pr_auc: 0.4002 - binary_accuracy: 0.9752 - precision: 0.6753 - recall: 0.7167  — val_f1_macro: 0.2290
#
# Epoch 46: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 80s 680ms/step - loss: 1.7133 - auc_roc: 0.9385 - pr_auc: 0.4001 - binary_accuracy: 0.9752 - precision: 0.6752 - recall: 0.7168 - val_loss: 2.4993 - val_auc_roc: 0.8554 - val_pr_auc: 0.2589 - val_binary_accuracy: 0.9710 - val_precision: 0.6305 - val_recall: 0.6282 - val_f1_macro: 0.2290 - lr: 3.7500e-05
# Epoch 47/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.7001 - auc_roc: 0.9361 - pr_auc: 0.4009 - binary_accuracy: 0.9755 - precision: 0.6805 - recall: 0.7168  — val_f1_macro: 0.2274
#
# Epoch 47: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 79s 675ms/step - loss: 1.7005 - auc_roc: 0.9361 - pr_auc: 0.4008 - binary_accuracy: 0.9755 - precision: 0.6805 - recall: 0.7167 - val_loss: 2.5430 - val_auc_roc: 0.8606 - val_pr_auc: 0.2619 - val_binary_accuracy: 0.9714 - val_precision: 0.6336 - val_recall: 0.6427 - val_f1_macro: 0.2274 - lr: 3.7500e-05
# Epoch 48/100
# 118/118 [==============================] - ETA: 0s - loss: 1.6916 - auc_roc: 0.9378 - pr_auc: 0.3905 - binary_accuracy: 0.9755 - precision: 0.6784 - recall: 0.7214  — val_f1_macro: 0.2238
#
# Epoch 48: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 81s 685ms/step - loss: 1.6916 - auc_roc: 0.9378 - pr_auc: 0.3905 - binary_accuracy: 0.9755 - precision: 0.6784 - recall: 0.7214 - val_loss: 2.6867 - val_auc_roc: 0.8574 - val_pr_auc: 0.2600 - val_binary_accuracy: 0.9703 - val_precision: 0.6184 - val_recall: 0.6372 - val_f1_macro: 0.2238 - lr: 3.7500e-05
# Epoch 49/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.6798 - auc_roc: 0.9385 - pr_auc: 0.3977 - binary_accuracy: 0.9754 - precision: 0.6775 - recall: 0.7207  — val_f1_macro: 0.2228
#
# Epoch 49: val_f1_macro did not improve from 0.23390
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 118/118 [==============================] - 79s 674ms/step - loss: 1.6808 - auc_roc: 0.9385 - pr_auc: 0.3976 - binary_accuracy: 0.9754 - precision: 0.6775 - recall: 0.7205 - val_loss: 2.5928 - val_auc_roc: 0.8611 - val_pr_auc: 0.2727 - val_binary_accuracy: 0.9710 - val_precision: 0.6347 - val_recall: 0.6177 - val_f1_macro: 0.2228 - lr: 3.7500e-05
# Epoch 50/100
# 118/118 [==============================] - ETA: 0s - loss: 1.6655 - auc_roc: 0.9398 - pr_auc: 0.4008 - binary_accuracy: 0.9757 - precision: 0.6800 - recall: 0.7260  — val_f1_macro: 0.2307
#
# Epoch 50: val_f1_macro did not improve from 0.23390
# 118/118 [==============================] - 81s 687ms/step - loss: 1.6655 - auc_roc: 0.9398 - pr_auc: 0.4008 - binary_accuracy: 0.9757 - precision: 0.6800 - recall: 0.7260 - val_loss: 2.5258 - val_auc_roc: 0.8543 - val_pr_auc: 0.2765 - val_binary_accuracy: 0.9714 - val_precision: 0.6329 - val_recall: 0.6458 - val_f1_macro: 0.2307 - lr: 1.8750e-05
# Epoch 51/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.6564 - auc_roc: 0.9387 - pr_auc: 0.4092 - binary_accuracy: 0.9760 - precision: 0.6855 - recall: 0.7287  — val_f1_macro: 0.2295
#
# Epoch 51: val_f1_macro did not improve from 0.23390
# Restoring model weights from the end of the best epoch: 41.
# 118/118 [==============================] - 80s 681ms/step - loss: 1.6566 - auc_roc: 0.9386 - pr_auc: 0.4091 - binary_accuracy: 0.9760 - precision: 0.6855 - recall: 0.7287 - val_loss: 2.5601 - val_auc_roc: 0.8539 - val_pr_auc: 0.2779 - val_binary_accuracy: 0.9713 - val_precision: 0.6321 - val_recall: 0.6440 - val_f1_macro: 0.2295 - lr: 1.8750e-05
# Epoch 51: early stopping

# %%
def summarize_history(history):
    history_df = pd.DataFrame(history.history)
    print("Last epoch metrics:")
    print(history_df.tail(1).round(4).to_string(index=False))

    if "val_auc_roc" in history_df.columns:
        best_epoch = int(history_df["val_auc_roc"].idxmax()) + 1

        best_val_auc = float(history_df["val_auc_roc"].max())
        print(f"Best validation AUC epoch: {best_epoch}")
        print(f"Best validation AUC: {best_val_auc:.4f}")

    return history_df


def plot_history(history_df):
    if history_df.empty:
        print("No history to plot.")
        return None

    epochs = range(1, len(history_df) + 1)
    fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

    if "loss" in history_df.columns:
        axes[0].plot(epochs, history_df["loss"], marker="o", label="loss")
    if "val_loss" in history_df.columns:
        axes[0].plot(epochs, history_df["val_loss"], marker="o", label="val_loss")
    axes[0].set_title("Loss")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    if "binary_accuracy" in history_df.columns:
        axes[1].plot(epochs, history_df["binary_accuracy"], marker="o", label="binary_accuracy")
    if "val_binary_accuracy" in history_df.columns:
        axes[1].plot(epochs, history_df["val_binary_accuracy"], marker="o", label="val_binary_accuracy")
    axes[1].set_title("Binary Accuracy")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

# في plot_history
    if "auc_roc" in history_df.columns:
        axes[2].plot(epochs, history_df["auc_roc"], label="auc_roc")
    if "val_auc_roc" in history_df.columns:
        axes[2].plot(epochs, history_df["val_auc_roc"], label="val_auc_roc")
        
    axes[2].set_title("AUC")
    axes[2].set_xlabel("Epoch")
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()
    return fig



def safe_multilabel_auc(y_true, y_score, average):
    y_true = np.array(y_true)
    y_score = np.array(y_score)

    valid_columns = []
    for i in range(y_true.shape[1]):
        positive_count = y_true[:, i].sum()
        if 0 < positive_count < len(y_true):
            valid_columns.append(i)

    if not valid_columns:
        return np.nan

    return float(roc_auc_score(y_true[:, valid_columns], y_score[:, valid_columns], average=average))


def batched_multimodal_predict(model, x_signal, x_csv, batch_size=None):
    """بتقييم الموديل على batches صغيرة لتجنب MemoryError"""
    if batch_size is None:
        batch_size = PREDICT_BATCH_SIZE   # <<< استخدام batch أصغر

    if len(x_signal) != len(x_csv):
        raise ValueError(f"signals/features mismatch -> {len(x_signal)} vs {len(x_csv)}")

    predictions = []
    for start in range(0, len(x_signal), batch_size):
        end = min(start + batch_size, len(x_signal))
        signal_batch = np.array(x_signal[start:end], dtype=np.float32)
        csv_batch = np.array(x_csv[start:end], dtype=np.float32)
        batch_prediction = model([signal_batch, csv_batch], training=False).numpy()
        predictions.append(batch_prediction)

        # تحرير الذاكرة بعد كل batch
        del signal_batch, csv_batch
        gc.collect()

    if not predictions:
        return np.empty((0, model.output_shape[-1]), dtype=np.float32)

    return np.vstack(predictions).astype(np.float32)




def evaluate_multimodal_predictions(y_true, y_score, split_name, threshold=METRIC_THRESHOLD):
    y_true = np.array(y_true, dtype=np.float32)
    y_score = np.array(y_score, dtype=np.float32)
    threshold_array = np.array(threshold, dtype=np.float32)
    y_pred = (y_score >= threshold_array).astype(np.float32)

    return {
        "split": split_name,
        "threshold": float(threshold_array.mean()) if threshold_array.ndim else float(threshold_array),
        "threshold_kind": "per_class" if threshold_array.ndim else "global",
        "binary_accuracy": float((y_pred == y_true).mean()),
        "f1_micro": float(f1_score(y_true, y_pred, average="micro", zero_division=0)),
        "f1_macro": float(f1_score(y_true, y_pred, average="macro", zero_division=0)),
        "f1_weighted": float(f1_score(y_true, y_pred, average="weighted", zero_division=0)),
        "auc_micro": safe_multilabel_auc(y_true, y_score, average="micro"),
        "auc_macro": safe_multilabel_auc(y_true, y_score, average="macro"),
    }


def tune_global_threshold(y_true, y_score, grid=THRESHOLD_SEARCH_GRID, optimize_metric="f1_macro"):
    best_metrics = None
    for threshold in np.array(grid, dtype=np.float32):
        metrics = evaluate_multimodal_predictions(y_true, y_score, "validation", threshold=float(threshold))
        if best_metrics is None or metrics[optimize_metric] > best_metrics[optimize_metric]:
            best_metrics = metrics
    return best_metrics


def tune_per_class_thresholds(y_true, y_score, class_names=None, grid=THRESHOLD_SEARCH_GRID):
    y_true = np.array(y_true, dtype=np.float32)
    y_score = np.array(y_score, dtype=np.float32)
    thresholds = np.full(y_true.shape[1], METRIC_THRESHOLD, dtype=np.float32)
    rows = []

    for idx in range(y_true.shape[1]):
        best_threshold = float(METRIC_THRESHOLD)
        best_f1 = -1.0
        label_true = y_true[:, idx]
        label_score = y_score[:, idx]

        for threshold in np.array(grid, dtype=np.float32):
            label_pred = (label_score >= threshold).astype(np.float32)
            label_f1 = float(f1_score(label_true, label_pred, zero_division=0))
            if label_f1 > best_f1:
                best_f1 = label_f1
                best_threshold = float(threshold)

        thresholds[idx] = best_threshold
        label_name = class_names[idx] if class_names is not None else idx
        rows.append({
            "label": str(label_name),
            "support": int(label_true.sum()),
            "threshold": best_threshold,
            "best_label_f1": best_f1,
        })

    thresholds_df = pd.DataFrame(rows).sort_values(["support", "threshold", "label"], ascending=[False, True, True]).reset_index(drop=True)
    return thresholds, thresholds_df

# %%
history_df = summarize_history(history)
# Out:
# Last epoch metrics:
#   loss  auc_roc  pr_auc  binary_accuracy  precision  recall  val_loss  val_auc_roc  val_pr_auc  val_binary_accuracy  val_precision  val_recall  val_f1_macro  lr
# 1.6566   0.9386  0.4091            0.976     0.6855  0.7287    2.5601       0.8539      0.2779               0.9713         0.6321       0.644        0.2295 0.0
# Best validation AUC epoch: 32
# Best validation AUC: 0.8655

# %%
print("=" * 60)
print("🔍 Step 1: Generating predictions on validation set...")
print("=" * 60)
val_score = batched_multimodal_predict(model, X_val_signal, X_val_csv)
gc.collect()

print("\n" + "=" * 60)
print("🔍 Step 2: Evaluating with FIXED threshold (0.5)...")
print("=" * 60)
fixed_metrics = evaluate_multimodal_predictions(y_val, val_score, "validation_fixed_0.5", threshold=METRIC_THRESHOLD)
print(pd.DataFrame([fixed_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 3: Tuning GLOBAL threshold...")
print("=" * 60)
best_global_metrics = tune_global_threshold(y_val, val_score)
best_global_threshold = best_global_metrics["threshold"]
print(f"Best global threshold: {best_global_threshold}")
print(pd.DataFrame([best_global_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 4: Tuning PER-CLASS thresholds...")
print("=" * 60)
per_class_thresholds, thresholds_df = tune_per_class_thresholds(
    y_val, val_score, class_names=mlb.classes_
)
print("\nPer-class thresholds:")
print(thresholds_df.to_string(index=False))

per_class_val_metrics = evaluate_multimodal_predictions(
    y_val, val_score, "validation_per_class", threshold=per_class_thresholds
)
print("\nValidation metrics with per-class thresholds:")
print(pd.DataFrame([per_class_val_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 5: Generating predictions on TEST set...")
print("=" * 60)
test_score = batched_multimodal_predict(model, X_test_signal, X_test_csv)
gc.collect()

print("\n" + "=" * 60)
print("📊 Step 6: Final TEST evaluation — comparison")
print("=" * 60)

# مقارنة: threshold ثابت vs global tuned vs per-class
test_fixed = evaluate_multimodal_predictions(y_test, test_score, "test_fixed_0.5", threshold=0.5)
test_global = evaluate_multimodal_predictions(y_test, test_score, f"test_global_{best_global_threshold}", threshold=best_global_threshold)
test_per_class = evaluate_multimodal_predictions(y_test, test_score, "test_per_class", threshold=per_class_thresholds)

comparison_df = pd.DataFrame([test_fixed, test_global, test_per_class]).set_index("split").round(4)
print("\n🏆 Test Results Comparison:")
print(comparison_df.to_string())
print("\n✅ Per-class thresholds should give the BEST F1 scores!")

# حفظ الـ per-class thresholds للاستخدام في الـ production
np.save(BASE_DIR / "per_class_thresholds.npy", per_class_thresholds)
print(f"\n💾 Per-class thresholds saved to: {BASE_DIR / 'per_class_thresholds.npy'}")
# Out:
# ============================================================
# 🔍 Step 1: Generating predictions on validation set...
# ============================================================
#
# ============================================================
# 🔍 Step 2: Evaluating with FIXED threshold (0.5)...
# ============================================================
#                       threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation_fixed_0.5        0.5         global            0.972     0.649    0.2339       0.6209     0.9563     0.8565
#
# ============================================================
# 🔍 Step 3: Tuning GLOBAL threshold...
# ============================================================
# Best global threshold: 0.36000001430511475
#             threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation       0.36         global           0.9376    0.5075    0.2458       0.6082     0.9563     0.8565
#
# ============================================================
# 🔍 Step 4: Tuning PER-CLASS thresholds...
# ============================================================
#
# Per-class thresholds:
#   label  support  threshold  best_label_f1
#      SR     1670       0.39       0.920662
#    NORM      955       0.48       0.840410
#   ABQRS      322       0.35       0.466507
#     IMI      266       0.44       0.563694
#    ASMI      236       0.64       0.648649
#     LVH      210       0.59       0.463542
#     NDT      182       0.53       0.419913
#    LAFB      163       0.58       0.781609
#    AFIB      151       0.84       0.851351
#    ISC_      125       0.48       0.513699
#     PVC      114       0.42       0.736842
#   IRBBB      112       0.51       0.625899
#    STD_      101       0.53       0.533898
#   VCLVH       87       0.46       0.208791
#   STACH       83       0.65       0.623656
#    1AVB       80       0.44       0.437158
#    IVCD       78       0.41       0.190476
#   SARRH       77       0.48       0.126437
#    NST_       75       0.44       0.229730
#   ISCAL       66       0.44       0.377143
#   SBRAD       64       0.65       0.486957
#   QWAVE       55       0.46       0.330275
#   CRBBB       55       0.66       0.810811
#   CLBBB       54       0.55       0.830189
#    ILMI       47       0.50       0.300000
#    LOWT       44       0.48       0.352941
# LAO/LAE       43       0.40       0.200000
#     NT_       41       0.48       0.293103
#     PAC       40       0.29       0.099448
#     AMI       36       0.37       0.145455
#     LPR       34       0.46       0.333333
#    INVT       30       0.44       0.268293
#    ALMI       29       0.45       0.477612
#    PACE       29       0.58       0.823529
#   ISCIN       21       0.37       0.250000
#   INJAS       21       0.43       0.181818
#     LMI       20       0.38       0.196078
#   LVOLT       19       0.31       0.080000
#   ISCIL       18       0.34       0.150000
#    LPFB       18       0.38       0.363636
#     DIG       18       0.53       0.378378
#   ISCAS       17       0.34       0.190476
#   SVARR       15       0.21       0.047138
#   INJAL       15       0.27       0.077670
#   ISCLA       14       0.32       0.073171
#   LNGQT       12       0.38       0.153846
#     RVH       12       0.50       0.411765
#      EL       10       0.37       0.250000
#   ANEUR       10       0.38       0.171429
# RAO/RAE       10       0.41       0.190476
#    BIGU        8       0.48       0.363636
#   HVOLT        7       0.11       0.008487
#   ILBBB        7       0.33       0.315789
#     WPW        7       0.34       0.153846
#    AFLT        7       0.52       0.833333
#   IPLMI        5       0.31       0.285714
#   ISCAN        5       0.32       0.153846
#    TAB_        4       0.14       0.009501
#    IPMI        4       0.21       0.032000
#    STE_        3       0.10       0.005495
#   SEHYP        3       0.19       0.014388
#   SVTAC        3       0.26       0.068966
#    PSVT        3       0.29       0.111111
#   INJLA        2       0.09       0.002959
#   INJIL        2       0.13       0.010256
#    3AVB        2       0.16       0.018692
#   INJIN        2       0.23       0.137931
#   TRIGU        2       0.29       0.500000
#     PMI        2       0.34       0.666667
#    2AVB        1       0.18       0.015385
#  PRC(S)        1       0.26       1.000000
#
# Validation metrics with per-class thresholds:
#                       threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation_per_class     0.3954      per_class           0.9358    0.4674    0.3406       0.6559     0.9563     0.8565
#
# ============================================================
# 🔍 Step 5: Generating predictions on TEST set...
# ============================================================
#
# ============================================================
# 📊 Step 6: Final TEST evaluation — comparison
# ============================================================
#
# 🏆 Test Results Comparison:
#                                  threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# test_fixed_0.5                      0.5000         global           0.9717    0.6442    0.2252       0.6165     0.9583     0.8577
# test_global_0.36000001430511475     0.3600         global           0.9374    0.5064    0.2384       0.6079     0.9583     0.8577
# test_per_class                      0.3954      per_class           0.9346    0.4543    0.2689       0.6368     0.9583     0.8577
#
# ✅ Per-class thresholds should give the BEST F1 scores!
#
# 💾 Per-class thresholds saved to: d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\per_class_thresholds.npy
