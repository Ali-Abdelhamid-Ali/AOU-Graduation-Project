# %%
import ast
from pathlib import Path
import gc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras


from sklearn.metrics import f1_score, multilabel_confusion_matrix, roc_auc_score
from sklearn.preprocessing import MultiLabelBinarizer

from tensorflow.keras import mixed_precision, layers, Model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, ReLU, Add, MaxPooling1D,
    GlobalAveragePooling1D, Dense, Dropout, Concatenate
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
BASE_DIR = Path.cwd()
if not (BASE_DIR / "X_train_processed.npy").exists():
    BASE_DIR = Path(r"D:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification")

TRAIN_AUDIO_PATH = BASE_DIR / "X_train_processed.npy"
VAL_AUDIO_PATH = BASE_DIR / "X_val_processed.npy"
TEST_AUDIO_PATH = BASE_DIR / "X_test_processed.npy"

TRAIN_CSV_PATH = BASE_DIR / "ptbxl_train.csv"
VAL_CSV_PATH = BASE_DIR / "ptbxl_val.csv"
TEST_CSV_PATH = BASE_DIR / "ptbxl_test.csv"

CSV_FEATURE_COLUMNS = [
    "age",
    "sex",
    "height",
    "weight",
    "validated_by_human",
    "height_missing",
    "weight_missing",
]

EXPECTED_SIGNAL_SHAPE = (5000, 12)
BATCH_SIZE = 32
PREDICT_BATCH_SIZE = 6     
DOWNSAMPLE_STRIDE=5   
EPOCHS = 30
LEARNING_RATE = 3e-4
METRIC_THRESHOLD = 0.5
THRESHOLD_SEARCH_GRID = np.round(np.arange(0.05, 0.951, 0.01), 2)
POS_WEIGHTS_PATH = BASE_DIR / "pos_weights.npy"
USE_POS_WEIGHTS = False
POS_WEIGHTS_MAX_CAP = 10.0   

gpus = tf.config.list_physical_devices("GPU")
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass

policy_name = "mixed_float16" if gpus else "float32"
mixed_precision.set_global_policy(policy_name)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3070 Ti Laptop GPU, compute capability 8.6

# %%
def load_signal_npy(npy_path, mmap_mode="r"):
    signals = np.load(npy_path, allow_pickle=False, mmap_mode=mmap_mode)

    if signals.dtype != np.float32:
        signals = signals.astype(np.float32)

    if signals.ndim != 3 or tuple(signals.shape[1:]) != EXPECTED_SIGNAL_SHAPE:
        raise ValueError(
            f"Expected shape (N, {EXPECTED_SIGNAL_SHAPE[0]}, {EXPECTED_SIGNAL_SHAPE[1]}), got {signals.shape}"
        )

    return signals


def extract_codes_list(df):
    return df["scp_codes"].apply(lambda value: sorted(ast.literal_eval(value).keys()))


def build_feature_matrix(df, feature_cols):
    features = df[feature_cols].copy()

    bool_cols = features.select_dtypes(include=["bool"]).columns
    if len(bool_cols):
        features[bool_cols] = features[bool_cols].astype(np.float32)

    return features.astype(np.float32).to_numpy()


def assert_split_alignment(signals, features, labels, split_name):
    if len(signals) != len(features):
        raise ValueError(
            f"{split_name}: signals/features mismatch -> {len(signals)} vs {len(features)}"
        )

    if labels is not None and len(labels) != len(signals):
        raise ValueError(
            f"{split_name}: labels/signals mismatch -> {len(labels)} vs {len(signals)}"
        )

# %%
def asymmetric_loss(gamma_neg=4, gamma_pos=0, clip=0.05):
    """
    Ridnik et al. ICCV 2021
    gamma_neg=4, gamma_pos=0 هي القيم الموصى بها في الورقة
    clip=0.05 بيمنع الـ easy negatives من تخريب الـ training
    """
    def asl(y_true, y_pred):
        y_true = tf.cast(y_true, y_pred.dtype)
        
        # Asymmetric clipping
        y_pred_neg = tf.clip_by_value(y_pred + clip, 0, 1)
        
        # Probability margins
        xs_pos = y_pred
        xs_neg = 1 - y_pred_neg
        
        # Log probabilities
        los_pos = y_true * tf.math.log(tf.clip_by_value(xs_pos, 1e-7, 1))
        los_neg = (1 - y_true) * tf.math.log(tf.clip_by_value(xs_neg, 1e-7, 1))
        
        loss = los_pos + los_neg
        
        # Asymmetric focusing
        if gamma_neg > 0 or gamma_pos > 0:
            pt0 = xs_pos * y_true
            pt1 = xs_neg * (1 - y_true)
            pt = pt0 + pt1
            
            one_sided_gamma = gamma_pos * y_true + gamma_neg * (1 - y_true)
            one_sided_w = tf.pow(1 - pt, one_sided_gamma)
            loss *= one_sided_w
        
        return -tf.reduce_mean(tf.reduce_sum(loss, axis=-1))
    
    asl.__name__ = "asymmetric_loss"
    return asl

# %%
def build_multimodal_head(
    backbone,
    signal_shape,
    num_csv_features,
    num_classes,
    learning_rate=LEARNING_RATE,
    model_name="Multimodal_ECG",
):
    """
    Generic multimodal head — يشتغل مع InceptionTime أو XceptionTime.
    backbone: الموديل اللي بترجعه من build_*_backbone()
    """
    signal_input = Input(shape=signal_shape, dtype=tf.float32, name="signal_input")
    csv_input    = Input(shape=(num_csv_features,), dtype=tf.float32, name="csv_input")

    # Signal branch
    signal_features = backbone(signal_input)

    # CSV branch
    csv_x = Dense(64, activation="relu", dtype="float32", name="csv_dense1")(csv_input)
    csv_x = Dropout(0.15, name="csv_dropout1")(csv_x)
    csv_x = Dense(32, activation="relu", dtype="float32", name="csv_dense2")(csv_x)

    # Fusion
    merged = Concatenate(name="fusion")([signal_features, csv_x])

    # Classification head
    x = Dense(256, activation="relu", dtype="float32", name="head_dense1")(merged)
    x = Dropout(0.30, name="head_dropout1")(x)
    x = Dense(128, activation="relu", dtype="float32", name="head_dense2")(x)
    x = Dropout(0.20, name="head_dropout2")(x)
    output = Dense(num_classes, activation="sigmoid", dtype="float32", name="output")(x)

    model = Model(inputs=[signal_input, csv_input], outputs=output, name=model_name)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=asymmetric_loss(gamma_neg=4, gamma_pos=0, clip=0.05),        
        metrics=[
            tf.keras.metrics.AUC(name="auc_roc", multi_label=True),
            tf.keras.metrics.AUC(name="pr_auc", multi_label=True, curve="PR"),
            tf.keras.metrics.BinaryAccuracy(name="binary_accuracy"),
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
        ],
    )
    model.summary()
    return model

# %%
def _inception_module(x, nb_filters=32, kernel_sizes=(10, 20, 40), bottleneck_size=32, name="inception"):
    """
    القلب النابض في InceptionTime.
    
    الفكرة الأساسية: بدل ما نشوف الـ ECG بعين واحدة (kernel واحد)،
    بنشوفه بـ 4 عيون في نفس الوقت — كل عين بتشوف نطاق زمني مختلف.
    
    ليه؟ لأن الـ ECG events بيتفاوتوا في الحجم:
      - موجة P  →  صغيرة وسريعة  →  kernel صغير يمسكها
      - QRS complex  →  متوسطة  →  kernel متوسط
      - موجة T  →  كبيرة وبطيئة  →  kernel كبير
    
    الـ flow:
        x
        ├─ Bottleneck (تضغط الـ channels لتوفير VRAM)
        │   ├─ Conv(k=10)  →  branch_1
        │   ├─ Conv(k=20)  →  branch_2  
        │   └─ Conv(k=40)  →  branch_3
        └─ MaxPool(3)  →  Conv(1)  →  branch_4
        
        [branch_1, branch_2, branch_3, branch_4]
        → Concatenate → BatchNorm → ReLU → output
    """

    in_channels = x.shape[-1]  # عدد الـ channels الداخلة (مثلاً 32 أو 128)

    # ── Step 1: Bottleneck ──────────────────────────────────────────────────────
    # المشكلة: لو عندنا 128 channel وعايزين نعمل Conv(k=40) عليهم
    #          ده هيكلف VRAM كتير جداً.
    # الحل: نضغط الـ channels لـ 32 الأول بـ Conv(1×1) (مش بتغير الـ time steps)
    #       وبعدين نعمل الـ parallel convs على الـ 32 الأصغر.
    # ملحوظة: لو الـ channels أصغر من bottleneck_size أصلاً → مش محتاجين نضغط
    if bottleneck_size is not None and in_channels is not None and in_channels > bottleneck_size:
        x_bottleneck = layers.Conv1D(
            bottleneck_size,    # نضغط لـ 32 channel
            kernel_size=1,      # 1×1 conv → بس بيغير الـ channels مش الـ time
            padding='same',
            use_bias=False,     # BatchNorm جاي بعدين، الـ bias مش مفيد هنا
            name=f"{name}_bottleneck"
        )(x)
    else:
        x_bottleneck = x  # خليها زي ما هي

    # ── Step 2: Parallel Convolutions (3 branches) ─────────────────────────────
    # كل branch بيشوف نطاق زمني مختلف من الـ signal
    branches = []
    for k in kernel_sizes:  # k = 10, 20, 40
        branch = layers.Conv1D(
            nb_filters,     # 32 filter لكل branch
            kernel_size=k,  # النافذة الزمنية
            padding='same', # نحافظ على نفس عدد الـ time steps
            use_bias=False,
            name=f"{name}_conv_k{k}"
        )(x_bottleneck)
        branches.append(branch)

    # ── Step 3: MaxPool Branch ──────────────────────────────────────────────────
    # الـ branch ده مش بيتعلم — بس بياخد أقوى قيمة في كل نافذة صغيرة.
    # بيمسك الـ peaks الواضحة في الـ signal (زي الـ R peak في QRS).
    # مهم: بيشتغل على x الأصلي (مش الـ bottleneck) عشان ميخسرش معلومات.
    mp = layers.MaxPooling1D(
        pool_size=3,    # بيشوف 3 نقاط ويرجع الأكبر
        strides=1,      # بيتحرك نقطة نقطة (مش بيقلل الـ time steps)
        padding='same',
        name=f"{name}_maxpool"
    )(x)
    
    # Conv(1×1) بعد الـ MaxPool عشان يضبط عدد الـ channels زي باقي الـ branches
    mp = layers.Conv1D(
        nb_filters,
        kernel_size=1,
        padding='same',
        use_bias=False,
        name=f"{name}_mp_conv"
    )(mp)
    
    branches.append(mp)  # دلوقتي عندنا 4 branches

    # ── Step 4: Merge ───────────────────────────────────────────────────────────
    # بنجمع الـ 4 branches جنب بعض على الـ channel axis
    # لو كل branch فيه 32 channel → بعد الـ concat هيبقى 32×4 = 128 channel
    out = layers.Concatenate(name=f"{name}_concat")(branches)
    
    # BatchNorm: بينظم الـ values ويسرع الـ training
    out = layers.BatchNormalization(name=f"{name}_bn")(out)
    
    # ReLU: بيعمل non-linearity (بيحول الـ negative values لـ 0)
    out = layers.ReLU(name=f"{name}_relu")(out)
    
    return out  # shape: (batch, time_steps, 128)


def build_inceptiontime_backbone(
    input_shape=(5000, 12),   # 5 ثواني × 500Hz × 12 lead
    nb_filters=32,            # filters في كل branch داخل الـ inception
    depth=6,                  # عدد الـ inception modules (6 في البيبر الأصلي)
    kernel_sizes=(10, 20, 40),
    bottleneck_size=32,
    downsample_stride=5,      # 5 → بيقلل 5000 timestep لـ 1000
):
    """
    الـ backbone كله — بياخد ECG signal خام ويرجع feature vector جاهز للتصنيف.
    
    الـ flow الكامل:
    
    Input (batch, 5000, 12)
         │
         ▼
    [Downsample] Conv1D(stride=5) → BN → ReLU
    (batch, 1000, 32)
         │
         ├─────────────────── residual_0 = x
         │
         ▼
    Inception_0  →  Inception_1  →  Inception_2
                                         │
                                    Add(x + shortcut)  ← Conv1D(residual_0)
                                    residual_1 = x
         │
         ▼
    Inception_3  →  Inception_4  →  Inception_5
                                         │
                                    Add(x + shortcut)  ← Conv1D(residual_1)
         │
         ▼
    GlobalAveragePooling1D
    (batch, 128)  ← feature vector جاهز
    """

    inputs = layers.Input(shape=input_shape, name="ecg_input")

    # ── Step 1: Downsampling ────────────────────────────────────────────────────
    # المشكلة: 5000 timestep كتير جداً على الـ GPU (خصوصاً مع batch_size صغير).
    # الحل: Conv1D بـ stride=5 تبقى 1000 timestep — نفس المعلومات تقريباً، VRAM أقل بكتير.
    # kernel_size = stride*2 = 10 عشان يشوف نافذة كافية قبل ما يقفز.
    if downsample_stride > 1:
        x = layers.Conv1D(
            nb_filters,
            kernel_size=downsample_stride * 2,
            strides=downsample_stride,
            padding='same',
            use_bias=False,
            name="initial_downsample"
        )(inputs)
        x = layers.BatchNormalization(name="initial_downsample_bn")(x)
        x = layers.ReLU(name="initial_downsample_relu")(x)
    else:
        x = inputs  # مفيش downsample → ابدأ من 5000 مباشرةً

    # ── Step 2: Residual Anchor ─────────────────────────────────────────────────
    # بنحفظ نسخة من x الحالي قبل ما ندخل الـ inception blocks.
    # هنستخدمها كـ "shortcut" بعد كل 3 blocks (زي ResNet).
    # الهدف: لو الـ inception blocks اتعلموا حاجة غلط → الـ gradient يعدي
    #         عن طريق الـ shortcut بدل ما يـ vanish.
    residual = x

    # عدد الـ output channels من كل inception module:
    # 3 parallel convs + 1 maxpool branch = 4 branches × 32 filter = 128
    n_out_channels = nb_filters * (len(kernel_sizes) + 1)

    # ── Step 3: Inception Blocks ────────────────────────────────────────────────
    for i in range(depth):  # i = 0, 1, 2, 3, 4, 5
        x = _inception_module(
            x,
            nb_filters=nb_filters,
            kernel_sizes=kernel_sizes,
            bottleneck_size=bottleneck_size,
            name=f"inception_{i}"
        )

        # كل 3 blocks → residual shortcut
        # i=2 → (2+1)%3 == 0 ✓  →  أول shortcut
        # i=5 → (5+1)%3 == 0 ✓  →  تاني shortcut
        if (i + 1) % 3 == 0:
            # الـ residual ممكن channels-ها تختلف عن x الحالي
            # فبنعمل Conv(1×1) عشان نوحد الـ channels قبل الـ Add
            shortcut = layers.Conv1D(
                n_out_channels,
                kernel_size=1,
                padding='same',
                use_bias=False,
                name=f"res_conv_{i}"
            )(residual)
            shortcut = layers.BatchNormalization(name=f"res_bn_{i}")(shortcut)

            # بنضيف الـ shortcut على x الحالي (مش concatenate — Add)
            x = layers.Add(name=f"res_add_{i}")([x, shortcut])
            x = layers.ReLU(name=f"res_relu_{i}")(x)

            # نحدث الـ residual للـ shortcut الجاي
            residual = x

    # ── Step 4: Global Average Pooling ─────────────────────────────────────────
    # دلوقتي x شكله (batch, 1000, 128).
    # الـ classifier مش محتاج يعرف "فين" الـ feature في الـ time axis،
    # محتاج بس "إيه" الـ features الموجودة → نعمل average على كل الـ time steps.
    # النتيجة: (batch, 128) — vector واحد يمثل الـ ECG كله.
    x = GlobalAveragePooling1D(name="gap")(x)

    return Model(inputs=inputs, outputs=x, name="InceptionTime_Backbone")

def build_multimodal_inceptiontime(
    signal_shape,
    num_csv_features,
    num_classes,
    learning_rate=LEARNING_RATE,
    nb_filters=32,
    depth=6,
    downsample_stride=DOWNSAMPLE_STRIDE,
):

    backbone = build_inceptiontime_backbone(
        input_shape=signal_shape,
        nb_filters=nb_filters,
        depth=depth,
        downsample_stride=downsample_stride,
    )

    return build_multimodal_head(
        backbone=backbone,
        signal_shape=signal_shape,
        num_csv_features=num_csv_features,
        num_classes=num_classes,
        learning_rate=learning_rate,
        model_name="Multimodal_InceptionTime",
    )

# %%
train_df = pd.read_csv(TRAIN_CSV_PATH)
val_df = pd.read_csv(VAL_CSV_PATH)
test_df = pd.read_csv(TEST_CSV_PATH)

X_train_signal = load_signal_npy(TRAIN_AUDIO_PATH)
X_val_signal = load_signal_npy(VAL_AUDIO_PATH)
X_test_signal = load_signal_npy(TEST_AUDIO_PATH)

X_train_csv = build_feature_matrix(train_df, CSV_FEATURE_COLUMNS)
X_val_csv = build_feature_matrix(val_df, CSV_FEATURE_COLUMNS)
X_test_csv = build_feature_matrix(test_df, CSV_FEATURE_COLUMNS)

mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(extract_codes_list(train_df)).astype(np.float32)
y_val = mlb.transform(extract_codes_list(val_df)).astype(np.float32)
y_test = mlb.transform(extract_codes_list(test_df)).astype(np.float32)

assert_split_alignment(X_train_signal, X_train_csv, y_train, "train")
assert_split_alignment(X_val_signal, X_val_csv, y_val, "val")
assert_split_alignment(X_test_signal, X_test_csv, y_test, "test")

SIGNAL_SHAPE = X_train_signal.shape[1:]
NUM_CLASSES = y_train.shape[1]

print("Train signal:", X_train_signal.shape, X_train_signal.dtype)
print("Val signal:", X_val_signal.shape, X_val_signal.dtype)
print("Test signal:", X_test_signal.shape, X_test_signal.dtype)
print("Train CSV:", X_train_csv.shape, X_train_csv.dtype)
print("Labels:", NUM_CLASSES)
print("classes:", mlb.classes_[:].tolist())
# Out:
# Raw pos_weights summary: {'min': 1.0, 'median': 50.0, 'max': 50.0}
# Adjusted pos_weights summary: {'min': 1.0, 'median': 7.0711, 'max': 7.0711}
# Train signal: (17418, 5000, 12) float32
# Val signal: (2183, 5000, 12) float32
# Test signal: (2198, 5000, 12) float32
# Train CSV: (17418, 7) float32
# Labels: 71
# classes: ['1AVB', '2AVB', '3AVB', 'ABQRS', 'AFIB', 'AFLT', 'ALMI', 'AMI', 'ANEUR', 'ASMI', 'BIGU', 'CLBBB', 'CRBBB', 'DIG', 'EL', 'HVOLT', 'ILBBB', 'ILMI', 'IMI', 'INJAL', 'INJAS', 'INJIL', 'INJIN', 'INJLA', 'INVT', 'IPLMI', 'IPMI', 'IRBBB', 'ISCAL', 'ISCAN', 'ISCAS', 'ISCIL', 'ISCIN', 'ISCLA', 'ISC_', 'IVCD', 'LAFB', 'LAO/LAE', 'LMI', 'LNGQT', 'LOWT', 'LPFB', 'LPR', 'LVH', 'LVOLT', 'NDT', 'NORM', 'NST_', 'NT_', 'PAC', 'PACE', 'PMI', 'PRC(S)', 'PSVT', 'PVC', 'QWAVE', 'RAO/RAE', 'RVH', 'SARRH', 'SBRAD', 'SEHYP', 'SR', 'STACH', 'STD_', 'STE_', 'SVARR', 'SVTAC', 'TAB_', 'TRIGU', 'VCLVH', 'WPW']

# %%
model = build_multimodal_inceptiontime(
    signal_shape=SIGNAL_SHAPE,
    num_csv_features=X_train_csv.shape[1],
    num_classes=NUM_CLASSES,
    nb_filters=32,
    depth=6,
    downsample_stride=DOWNSAMPLE_STRIDE,
)

model.summary()
# Out:
# Model: "Multimodal_InceptionTime"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  csv_input (InputLayer)         [(None, 7)]          0           []
#
#  csv_dense1 (Dense)             (None, 64)           512         ['csv_input[0][0]']
#
#  signal_input (InputLayer)      [(None, 5000, 12)]   0           []
#
#  csv_dropout1 (Dropout)         (None, 64)           0           ['csv_dense1[0][0]']
#
#  InceptionTime_Backbone (Functi  (None, 128)         500608      ['signal_input[0][0]']
#  onal)
#
#  csv_dense2 (Dense)             (None, 32)           2080        ['csv_dropout1[0][0]']
#
#  fusion (Concatenate)           (None, 160)          0           ['InceptionTime_Backbone[0][0]',
#                                                                   'csv_dense2[0][0]']
#
#  head_dense1 (Dense)            (None, 256)          41216       ['fusion[0][0]']
#
#  head_dropout1 (Dropout)        (None, 256)          0           ['head_dense1[0][0]']
#
#  head_dense2 (Dense)            (None, 128)          32896       ['head_dropout1[0][0]']
#
#  head_dropout2 (Dropout)        (None, 128)          0           ['head_dense2[0][0]']
#
#  output (Dense)                 (None, 71)           9159        ['head_dropout2[0][0]']
#
# ==================================================================================================
# Total params: 586,471
# Trainable params: 584,359
# Non-trainable params: 2,112
# __________________________________________________________________________________________________
# Model: "Multimodal_InceptionTime"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  csv_input (InputLayer)         [(None, 7)]          0           []
#
#  csv_dense1 (Dense)             (None, 64)           512         ['csv_input[0][0]']
#
#  signal_input (InputLayer)      [(None, 5000, 12)]   0           []
#
#  csv_dropout1 (Dropout)         (None, 64)           0           ['csv_dense1[0][0]']
#
#  InceptionTime_Backbone (Functi  (None, 128)         500608      ['signal_input[0][0]']
#  onal)
#
#  csv_dense2 (Dense)             (None, 32)           2080        ['csv_dropout1[0][0]']
#
#  fusion (Concatenate)           (None, 160)          0           ['InceptionTime_Backbone[0][0]',
#                                                                   'csv_dense2[0][0]']
#
#  head_dense1 (Dense)            (None, 256)          41216       ['fusion[0][0]']
#
#  head_dropout1 (Dropout)        (None, 256)          0           ['head_dense1[0][0]']
#
#  head_dense2 (Dense)            (None, 128)          32896       ['head_dropout1[0][0]']
#
#  head_dropout2 (Dropout)        (None, 128)          0           ['head_dense2[0][0]']
#
#  output (Dense)                 (None, 71)           9159        ['head_dropout2[0][0]']
#
# ==================================================================================================
# Total params: 586,471
# Trainable params: 584,359
# Non-trainable params: 2,112
# __________________________________________________________________________________________________

# %%
class MacroF1Callback(tf.keras.callbacks.Callback):
    """
    بيحسب F1 macro على الـ validation set بعد كل epoch.
    أسرع من sklearn لأنه بيشتغل بـ numpy مباشرة.
    """
    def __init__(self, val_data, threshold=0.5):
        super().__init__()
        self.X_val_signal, self.X_val_csv = val_data[0]
        self.y_val = val_data[1]
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        predictions = []
        for start in range(0, len(self.X_val_signal), PREDICT_BATCH_SIZE):
            end = min(start + PREDICT_BATCH_SIZE, len(self.X_val_signal))
            batch_pred = self.model(
                [self.X_val_signal[start:end], self.X_val_csv[start:end]],
                training=False
            ).numpy()
            predictions.append(batch_pred)
            gc.collect()
        
        y_pred = np.vstack(predictions).astype(np.float32)
        y_pred_bin = (y_pred >= self.threshold).astype(np.float32)
        y_true = self.y_val

        # F1 per class ثم average — نفس منطق sklearn
        tp = (y_true * y_pred_bin).sum(axis=0)
        fp = ((1 - y_true) * y_pred_bin).sum(axis=0)
        fn = (y_true * (1 - y_pred_bin)).sum(axis=0)

        precision = tp / np.clip(tp + fp, 1e-7, None)
        recall    = tp / np.clip(tp + fn, 1e-7, None)
        f1_per_class = 2 * precision * recall / np.clip(precision + recall, 1e-7, None)

        # نتجاهل الـ classes اللي مفيش samples منها في الـ val
        valid_mask = y_true.sum(axis=0) > 0
        f1_macro = f1_per_class[valid_mask].mean()

        logs["val_f1_macro"] = float(f1_macro)
        print(f"  — val_f1_macro: {f1_macro:.4f}")



macro_f1_cb = MacroF1Callback(
    val_data=([X_val_signal, X_val_csv], y_val),
    threshold=0.5,
)

callbacks = [
    macro_f1_cb, 

    ModelCheckpoint(
        BASE_DIR / "ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5",
        monitor="val_f1_macro",  
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    ),

    EarlyStopping(
        monitor="val_f1_macro",   
        mode="max",
        patience=10,              
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_f1_macro",   
        factor=0.5,
        patience=4,               
        mode="max",
        min_lr=1e-6,           
        verbose=1,
    ),
]

# %%
history = model.fit(
    [X_train_signal, X_train_csv],
    y_train,
    validation_data=([X_val_signal, X_val_csv], y_val),
    epochs=100,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/100
# 545/545 [==============================] - ETA: 0s - loss: 2.7878 - auc_roc: 0.6838 - pr_auc: 0.0925 - binary_accuracy: 0.9511 - precision: 0.4088 - recall: 0.5342  — val_f1_macro: 0.0987
#
# Epoch 1: val_f1_macro improved from -inf to 0.09871, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 112s 174ms/step - loss: 2.7878 - auc_roc: 0.6838 - pr_auc: 0.0925 - binary_accuracy: 0.9511 - precision: 0.4088 - recall: 0.5342 - val_loss: 2.3294 - val_auc_roc: 0.7758 - val_pr_auc: 0.1595 - val_binary_accuracy: 0.9702 - val_precision: 0.6390 - val_recall: 0.5536 - val_f1_macro: 0.0987 - lr: 3.0000e-04
# Epoch 2/100
# 545/545 [==============================] - ETA: 0s - loss: 2.2312 - auc_roc: 0.7820 - pr_auc: 0.1633 - binary_accuracy: 0.9716 - precision: 0.6477 - recall: 0.6174  — val_f1_macro: 0.1302
#
# Epoch 2: val_f1_macro improved from 0.09871 to 0.13016, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 89s 162ms/step - loss: 2.2312 - auc_roc: 0.7820 - pr_auc: 0.1633 - binary_accuracy: 0.9716 - precision: 0.6477 - recall: 0.6174 - val_loss: 2.2952 - val_auc_roc: 0.8000 - val_pr_auc: 0.1870 - val_binary_accuracy: 0.9693 - val_precision: 0.6111 - val_recall: 0.5960 - val_f1_macro: 0.1302 - lr: 3.0000e-04
# Epoch 3/100
# 545/545 [==============================] - ETA: 0s - loss: 2.1057 - auc_roc: 0.8260 - pr_auc: 0.1950 - binary_accuracy: 0.9732 - precision: 0.6639 - recall: 0.6498  — val_f1_macro: 0.1642
#
# Epoch 3: val_f1_macro improved from 0.13016 to 0.16423, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 102s 187ms/step - loss: 2.1057 - auc_roc: 0.8260 - pr_auc: 0.1950 - binary_accuracy: 0.9732 - precision: 0.6639 - recall: 0.6498 - val_loss: 2.1179 - val_auc_roc: 0.8522 - val_pr_auc: 0.2259 - val_binary_accuracy: 0.9751 - val_precision: 0.7026 - val_recall: 0.6333 - val_f1_macro: 0.1642 - lr: 3.0000e-04
# Epoch 4/100
# 545/545 [==============================] - ETA: 0s - loss: 2.0229 - auc_roc: 0.8442 - pr_auc: 0.2203 - binary_accuracy: 0.9745 - precision: 0.6784 - recall: 0.6735  — val_f1_macro: 0.1886
#
# Epoch 4: val_f1_macro improved from 0.16423 to 0.18859, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 113s 207ms/step - loss: 2.0229 - auc_roc: 0.8442 - pr_auc: 0.2203 - binary_accuracy: 0.9745 - precision: 0.6784 - recall: 0.6735 - val_loss: 2.0246 - val_auc_roc: 0.8687 - val_pr_auc: 0.2429 - val_binary_accuracy: 0.9731 - val_precision: 0.6532 - val_recall: 0.6727 - val_f1_macro: 0.1886 - lr: 3.0000e-04
# Epoch 5/100
# 545/545 [==============================] - ETA: 0s - loss: 1.9860 - auc_roc: 0.8617 - pr_auc: 0.2329 - binary_accuracy: 0.9748 - precision: 0.6810 - recall: 0.6801  — val_f1_macro: 0.1865
#
# Epoch 5: val_f1_macro did not improve from 0.18859
# 545/545 [==============================] - 109s 199ms/step - loss: 1.9860 - auc_roc: 0.8617 - pr_auc: 0.2329 - binary_accuracy: 0.9748 - precision: 0.6810 - recall: 0.6801 - val_loss: 2.0379 - val_auc_roc: 0.8779 - val_pr_auc: 0.2515 - val_binary_accuracy: 0.9753 - val_precision: 0.6992 - val_recall: 0.6491 - val_f1_macro: 0.1865 - lr: 3.0000e-04
# Epoch 6/100
# 545/545 [==============================] - ETA: 0s - loss: 1.9392 - auc_roc: 0.8752 - pr_auc: 0.2429 - binary_accuracy: 0.9755 - precision: 0.6899 - recall: 0.6911  — val_f1_macro: 0.2289
#
# Epoch 6: val_f1_macro improved from 0.18859 to 0.22895, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 107s 196ms/step - loss: 1.9392 - auc_roc: 0.8752 - pr_auc: 0.2429 - binary_accuracy: 0.9755 - precision: 0.6899 - recall: 0.6911 - val_loss: 1.9565 - val_auc_roc: 0.8850 - val_pr_auc: 0.2729 - val_binary_accuracy: 0.9745 - val_precision: 0.6662 - val_recall: 0.7005 - val_f1_macro: 0.2289 - lr: 3.0000e-04
# Epoch 7/100
# 545/545 [==============================] - ETA: 0s - loss: 1.9314 - auc_roc: 0.8779 - pr_auc: 0.2491 - binary_accuracy: 0.9755 - precision: 0.6893 - recall: 0.6921  — val_f1_macro: 0.2027
#
# Epoch 7: val_f1_macro did not improve from 0.22895
# 545/545 [==============================] - 108s 198ms/step - loss: 1.9314 - auc_roc: 0.8779 - pr_auc: 0.2491 - binary_accuracy: 0.9755 - precision: 0.6893 - recall: 0.6921 - val_loss: 1.9644 - val_auc_roc: 0.8900 - val_pr_auc: 0.2744 - val_binary_accuracy: 0.9761 - val_precision: 0.7025 - val_recall: 0.6774 - val_f1_macro: 0.2027 - lr: 3.0000e-04
# Epoch 8/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.8644 - auc_roc: 0.8945 - pr_auc: 0.2676 - binary_accuracy: 0.9763 - precision: 0.6962 - recall: 0.7088  — val_f1_macro: 0.2213
#
# Epoch 8: val_f1_macro did not improve from 0.22895
# 545/545 [==============================] - 108s 199ms/step - loss: 1.8647 - auc_roc: 0.8946 - pr_auc: 0.2677 - binary_accuracy: 0.9763 - precision: 0.6962 - recall: 0.7087 - val_loss: 2.0759 - val_auc_roc: 0.8822 - val_pr_auc: 0.2762 - val_binary_accuracy: 0.9753 - val_precision: 0.6896 - val_recall: 0.6747 - val_f1_macro: 0.2213 - lr: 3.0000e-04
# Epoch 9/100
# 545/545 [==============================] - ETA: 0s - loss: 1.8476 - auc_roc: 0.8967 - pr_auc: 0.2782 - binary_accuracy: 0.9766 - precision: 0.6994 - recall: 0.7142  — val_f1_macro: 0.1854
#
# Epoch 9: val_f1_macro did not improve from 0.22895
# 545/545 [==============================] - 108s 198ms/step - loss: 1.8476 - auc_roc: 0.8967 - pr_auc: 0.2782 - binary_accuracy: 0.9766 - precision: 0.6994 - recall: 0.7142 - val_loss: 2.2042 - val_auc_roc: 0.8744 - val_pr_auc: 0.2643 - val_binary_accuracy: 0.9757 - val_precision: 0.7249 - val_recall: 0.6151 - val_f1_macro: 0.1854 - lr: 3.0000e-04
# Epoch 10/100
# 545/545 [==============================] - ETA: 0s - loss: 1.8343 - auc_roc: 0.9032 - pr_auc: 0.2774 - binary_accuracy: 0.9767 - precision: 0.7012 - recall: 0.7133  — val_f1_macro: 0.2335
#
# Epoch 10: val_f1_macro improved from 0.22895 to 0.23353, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 108s 199ms/step - loss: 1.8343 - auc_roc: 0.9032 - pr_auc: 0.2774 - binary_accuracy: 0.9767 - precision: 0.7012 - recall: 0.7133 - val_loss: 1.9928 - val_auc_roc: 0.8915 - val_pr_auc: 0.2890 - val_binary_accuracy: 0.9752 - val_precision: 0.6831 - val_recall: 0.6882 - val_f1_macro: 0.2335 - lr: 3.0000e-04
# Epoch 11/100
# 545/545 [==============================] - ETA: 0s - loss: 1.8262 - auc_roc: 0.9036 - pr_auc: 0.2847 - binary_accuracy: 0.9769 - precision: 0.7033 - recall: 0.7179  — val_f1_macro: 0.2175
#
# Epoch 11: val_f1_macro did not improve from 0.23353
# 545/545 [==============================] - 108s 198ms/step - loss: 1.8262 - auc_roc: 0.9036 - pr_auc: 0.2847 - binary_accuracy: 0.9769 - precision: 0.7033 - recall: 0.7179 - val_loss: 2.1876 - val_auc_roc: 0.8737 - val_pr_auc: 0.2765 - val_binary_accuracy: 0.9720 - val_precision: 0.6384 - val_recall: 0.6584 - val_f1_macro: 0.2175 - lr: 3.0000e-04
# Epoch 12/100
# 545/545 [==============================] - ETA: 0s - loss: 1.8059 - auc_roc: 0.9082 - pr_auc: 0.2903 - binary_accuracy: 0.9772 - precision: 0.7055 - recall: 0.7235  — val_f1_macro: 0.2450
#
# Epoch 12: val_f1_macro improved from 0.23353 to 0.24502, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 200ms/step - loss: 1.8059 - auc_roc: 0.9082 - pr_auc: 0.2903 - binary_accuracy: 0.9772 - precision: 0.7055 - recall: 0.7235 - val_loss: 1.9008 - val_auc_roc: 0.9033 - val_pr_auc: 0.2970 - val_binary_accuracy: 0.9742 - val_precision: 0.6568 - val_recall: 0.7193 - val_f1_macro: 0.2450 - lr: 3.0000e-04
# Epoch 13/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.7855 - auc_roc: 0.9139 - pr_auc: 0.3003 - binary_accuracy: 0.9773 - precision: 0.7064 - recall: 0.7261  — val_f1_macro: 0.2304
#
# Epoch 13: val_f1_macro did not improve from 0.24502
# 545/545 [==============================] - 108s 199ms/step - loss: 1.7854 - auc_roc: 0.9138 - pr_auc: 0.3003 - binary_accuracy: 0.9773 - precision: 0.7063 - recall: 0.7261 - val_loss: 1.9981 - val_auc_roc: 0.8907 - val_pr_auc: 0.2932 - val_binary_accuracy: 0.9768 - val_precision: 0.7206 - val_recall: 0.6680 - val_f1_macro: 0.2304 - lr: 3.0000e-04
# Epoch 14/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7812 - auc_roc: 0.9155 - pr_auc: 0.2979 - binary_accuracy: 0.9773 - precision: 0.7079 - recall: 0.7249  — val_f1_macro: 0.2491
#
# Epoch 14: val_f1_macro improved from 0.24502 to 0.24912, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7812 - auc_roc: 0.9155 - pr_auc: 0.2979 - binary_accuracy: 0.9773 - precision: 0.7079 - recall: 0.7249 - val_loss: 2.0233 - val_auc_roc: 0.8961 - val_pr_auc: 0.2933 - val_binary_accuracy: 0.9751 - val_precision: 0.6742 - val_recall: 0.7053 - val_f1_macro: 0.2491 - lr: 3.0000e-04
# Epoch 15/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7836 - auc_roc: 0.9159 - pr_auc: 0.2974 - binary_accuracy: 0.9771 - precision: 0.7045 - recall: 0.7229  — val_f1_macro: 0.2323
#
# Epoch 15: val_f1_macro did not improve from 0.24912
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7836 - auc_roc: 0.9159 - pr_auc: 0.2974 - binary_accuracy: 0.9771 - precision: 0.7045 - recall: 0.7229 - val_loss: 2.1400 - val_auc_roc: 0.8863 - val_pr_auc: 0.2949 - val_binary_accuracy: 0.9751 - val_precision: 0.6962 - val_recall: 0.6504 - val_f1_macro: 0.2323 - lr: 3.0000e-04
# Epoch 16/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7743 - auc_roc: 0.9183 - pr_auc: 0.3022 - binary_accuracy: 0.9773 - precision: 0.7066 - recall: 0.7261  — val_f1_macro: 0.2546
#
# Epoch 16: val_f1_macro improved from 0.24912 to 0.25463, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 107s 197ms/step - loss: 1.7743 - auc_roc: 0.9183 - pr_auc: 0.3022 - binary_accuracy: 0.9773 - precision: 0.7066 - recall: 0.7261 - val_loss: 1.9855 - val_auc_roc: 0.9031 - val_pr_auc: 0.3006 - val_binary_accuracy: 0.9757 - val_precision: 0.6818 - val_recall: 0.7150 - val_f1_macro: 0.2546 - lr: 3.0000e-04
# Epoch 17/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7766 - auc_roc: 0.9213 - pr_auc: 0.3047 - binary_accuracy: 0.9773 - precision: 0.7075 - recall: 0.7265  — val_f1_macro: 0.2405
#
# Epoch 17: val_f1_macro did not improve from 0.25463
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7766 - auc_roc: 0.9213 - pr_auc: 0.3047 - binary_accuracy: 0.9773 - precision: 0.7075 - recall: 0.7265 - val_loss: 1.9824 - val_auc_roc: 0.8971 - val_pr_auc: 0.2993 - val_binary_accuracy: 0.9737 - val_precision: 0.6505 - val_recall: 0.7125 - val_f1_macro: 0.2405 - lr: 3.0000e-04
# Epoch 18/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7353 - auc_roc: 0.9239 - pr_auc: 0.3152 - binary_accuracy: 0.9780 - precision: 0.7151 - recall: 0.7358  — val_f1_macro: 0.2557
#
# Epoch 18: val_f1_macro improved from 0.25463 to 0.25573, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7353 - auc_roc: 0.9239 - pr_auc: 0.3152 - binary_accuracy: 0.9780 - precision: 0.7151 - recall: 0.7358 - val_loss: 1.9729 - val_auc_roc: 0.9071 - val_pr_auc: 0.3108 - val_binary_accuracy: 0.9767 - val_precision: 0.7045 - val_recall: 0.6995 - val_f1_macro: 0.2557 - lr: 3.0000e-04
# Epoch 19/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7494 - auc_roc: 0.9217 - pr_auc: 0.3136 - binary_accuracy: 0.9776 - precision: 0.7107 - recall: 0.7306  — val_f1_macro: 0.2059
#
# Epoch 19: val_f1_macro did not improve from 0.25573
# 545/545 [==============================] - 108s 199ms/step - loss: 1.7494 - auc_roc: 0.9217 - pr_auc: 0.3136 - binary_accuracy: 0.9776 - precision: 0.7107 - recall: 0.7306 - val_loss: 2.4214 - val_auc_roc: 0.8753 - val_pr_auc: 0.2805 - val_binary_accuracy: 0.9666 - val_precision: 0.5705 - val_recall: 0.6021 - val_f1_macro: 0.2059 - lr: 3.0000e-04
# Epoch 20/100
# 545/545 [==============================] - ETA: 0s - loss: 1.7376 - auc_roc: 0.9244 - pr_auc: 0.3173 - binary_accuracy: 0.9778 - precision: 0.7121 - recall: 0.7337  — val_f1_macro: 0.2549
#
# Epoch 20: val_f1_macro did not improve from 0.25573
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7376 - auc_roc: 0.9244 - pr_auc: 0.3173 - binary_accuracy: 0.9778 - precision: 0.7121 - recall: 0.7337 - val_loss: 1.9035 - val_auc_roc: 0.9103 - val_pr_auc: 0.3148 - val_binary_accuracy: 0.9765 - val_precision: 0.7001 - val_recall: 0.7023 - val_f1_macro: 0.2549 - lr: 3.0000e-04
# Epoch 21/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.7199 - auc_roc: 0.9275 - pr_auc: 0.3284 - binary_accuracy: 0.9779 - precision: 0.7124 - recall: 0.7383  — val_f1_macro: 0.2534
#
# Epoch 21: val_f1_macro did not improve from 0.25573
# 545/545 [==============================] - 109s 199ms/step - loss: 1.7196 - auc_roc: 0.9275 - pr_auc: 0.3284 - binary_accuracy: 0.9779 - precision: 0.7123 - recall: 0.7383 - val_loss: 1.9581 - val_auc_roc: 0.9049 - val_pr_auc: 0.3196 - val_binary_accuracy: 0.9765 - val_precision: 0.7029 - val_recall: 0.6943 - val_f1_macro: 0.2534 - lr: 3.0000e-04
# Epoch 22/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.6954 - auc_roc: 0.9318 - pr_auc: 0.3309 - binary_accuracy: 0.9782 - precision: 0.7157 - recall: 0.7414  — val_f1_macro: 0.2474
#
# Epoch 22: val_f1_macro did not improve from 0.25573
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 545/545 [==============================] - 108s 198ms/step - loss: 1.6955 - auc_roc: 0.9318 - pr_auc: 0.3309 - binary_accuracy: 0.9782 - precision: 0.7158 - recall: 0.7414 - val_loss: 2.0008 - val_auc_roc: 0.8990 - val_pr_auc: 0.3114 - val_binary_accuracy: 0.9739 - val_precision: 0.6563 - val_recall: 0.7050 - val_f1_macro: 0.2474 - lr: 3.0000e-04
# Epoch 23/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.6042 - auc_roc: 0.9373 - pr_auc: 0.3526 - binary_accuracy: 0.9792 - precision: 0.7270 - recall: 0.7579  — val_f1_macro: 0.2657
#
# Epoch 23: val_f1_macro improved from 0.25573 to 0.26570, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 199ms/step - loss: 1.6044 - auc_roc: 0.9373 - pr_auc: 0.3526 - binary_accuracy: 0.9792 - precision: 0.7269 - recall: 0.7579 - val_loss: 1.9168 - val_auc_roc: 0.9118 - val_pr_auc: 0.3238 - val_binary_accuracy: 0.9760 - val_precision: 0.6865 - val_recall: 0.7158 - val_f1_macro: 0.2657 - lr: 1.5000e-04
# Epoch 24/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.5865 - auc_roc: 0.9414 - pr_auc: 0.3564 - binary_accuracy: 0.9793 - precision: 0.7272 - recall: 0.7594  — val_f1_macro: 0.2744
#
# Epoch 24: val_f1_macro improved from 0.26570 to 0.27438, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 108s 199ms/step - loss: 1.5866 - auc_roc: 0.9414 - pr_auc: 0.3564 - binary_accuracy: 0.9793 - precision: 0.7272 - recall: 0.7594 - val_loss: 2.0165 - val_auc_roc: 0.9121 - val_pr_auc: 0.3213 - val_binary_accuracy: 0.9768 - val_precision: 0.6999 - val_recall: 0.7165 - val_f1_macro: 0.2744 - lr: 1.5000e-04
# Epoch 25/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.5812 - auc_roc: 0.9405 - pr_auc: 0.3518 - binary_accuracy: 0.9794 - precision: 0.7293 - recall: 0.7588  — val_f1_macro: 0.2644
#
# Epoch 25: val_f1_macro did not improve from 0.27438
# 545/545 [==============================] - 108s 197ms/step - loss: 1.5812 - auc_roc: 0.9405 - pr_auc: 0.3517 - binary_accuracy: 0.9793 - precision: 0.7292 - recall: 0.7587 - val_loss: 1.9676 - val_auc_roc: 0.9119 - val_pr_auc: 0.3199 - val_binary_accuracy: 0.9766 - val_precision: 0.6977 - val_recall: 0.7135 - val_f1_macro: 0.2644 - lr: 1.5000e-04
# Epoch 26/100
# 545/545 [==============================] - ETA: 0s - loss: 1.5725 - auc_roc: 0.9410 - pr_auc: 0.3541 - binary_accuracy: 0.9795 - precision: 0.7311 - recall: 0.7626  — val_f1_macro: 0.2719
#
# Epoch 26: val_f1_macro did not improve from 0.27438
# 545/545 [==============================] - 110s 201ms/step - loss: 1.5725 - auc_roc: 0.9410 - pr_auc: 0.3541 - binary_accuracy: 0.9795 - precision: 0.7311 - recall: 0.7626 - val_loss: 2.0861 - val_auc_roc: 0.9132 - val_pr_auc: 0.3199 - val_binary_accuracy: 0.9763 - val_precision: 0.6892 - val_recall: 0.7235 - val_f1_macro: 0.2719 - lr: 1.5000e-04
# Epoch 27/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.5812 - auc_roc: 0.9410 - pr_auc: 0.3569 - binary_accuracy: 0.9794 - precision: 0.7293 - recall: 0.7586  — val_f1_macro: 0.2593
#
# Epoch 27: val_f1_macro did not improve from 0.27438
# 545/545 [==============================] - 107s 196ms/step - loss: 1.5818 - auc_roc: 0.9410 - pr_auc: 0.3568 - binary_accuracy: 0.9793 - precision: 0.7292 - recall: 0.7585 - val_loss: 2.0449 - val_auc_roc: 0.9042 - val_pr_auc: 0.3040 - val_binary_accuracy: 0.9756 - val_precision: 0.6813 - val_recall: 0.7106 - val_f1_macro: 0.2593 - lr: 1.5000e-04
# Epoch 28/100
# 545/545 [==============================] - ETA: 0s - loss: 1.5601 - auc_roc: 0.9434 - pr_auc: 0.3647 - binary_accuracy: 0.9794 - precision: 0.7295 - recall: 0.7619  — val_f1_macro: 0.2725
#
# Epoch 28: val_f1_macro did not improve from 0.27438
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 545/545 [==============================] - 108s 198ms/step - loss: 1.5601 - auc_roc: 0.9434 - pr_auc: 0.3647 - binary_accuracy: 0.9794 - precision: 0.7295 - recall: 0.7619 - val_loss: 2.0502 - val_auc_roc: 0.9076 - val_pr_auc: 0.3237 - val_binary_accuracy: 0.9754 - val_precision: 0.6785 - val_recall: 0.7107 - val_f1_macro: 0.2725 - lr: 1.5000e-04
# Epoch 29/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4914 - auc_roc: 0.9469 - pr_auc: 0.3808 - binary_accuracy: 0.9802 - precision: 0.7388 - recall: 0.7726  — val_f1_macro: 0.2772
#
# Epoch 29: val_f1_macro improved from 0.27438 to 0.27721, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 200ms/step - loss: 1.4914 - auc_roc: 0.9469 - pr_auc: 0.3808 - binary_accuracy: 0.9802 - precision: 0.7388 - recall: 0.7726 - val_loss: 2.1146 - val_auc_roc: 0.9120 - val_pr_auc: 0.3232 - val_binary_accuracy: 0.9767 - val_precision: 0.6956 - val_recall: 0.7245 - val_f1_macro: 0.2772 - lr: 7.5000e-05
# Epoch 30/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4989 - auc_roc: 0.9480 - pr_auc: 0.3749 - binary_accuracy: 0.9802 - precision: 0.7389 - recall: 0.7713  — val_f1_macro: 0.2760
#
# Epoch 30: val_f1_macro did not improve from 0.27721
# 545/545 [==============================] - 108s 198ms/step - loss: 1.4989 - auc_roc: 0.9480 - pr_auc: 0.3749 - binary_accuracy: 0.9802 - precision: 0.7389 - recall: 0.7713 - val_loss: 2.1724 - val_auc_roc: 0.9121 - val_pr_auc: 0.3272 - val_binary_accuracy: 0.9766 - val_precision: 0.6965 - val_recall: 0.7161 - val_f1_macro: 0.2760 - lr: 7.5000e-05
# Epoch 31/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.4736 - auc_roc: 0.9484 - pr_auc: 0.3802 - binary_accuracy: 0.9804 - precision: 0.7399 - recall: 0.7755  — val_f1_macro: 0.2804
#
# Epoch 31: val_f1_macro improved from 0.27721 to 0.28044, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 109s 200ms/step - loss: 1.4736 - auc_roc: 0.9484 - pr_auc: 0.3802 - binary_accuracy: 0.9804 - precision: 0.7399 - recall: 0.7755 - val_loss: 2.1379 - val_auc_roc: 0.9117 - val_pr_auc: 0.3224 - val_binary_accuracy: 0.9766 - val_precision: 0.6929 - val_recall: 0.7267 - val_f1_macro: 0.2804 - lr: 7.5000e-05
# Epoch 32/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4545 - auc_roc: 0.9498 - pr_auc: 0.3830 - binary_accuracy: 0.9803 - precision: 0.7386 - recall: 0.7757  — val_f1_macro: 0.2743
#
# Epoch 32: val_f1_macro did not improve from 0.28044
# 545/545 [==============================] - 108s 198ms/step - loss: 1.4545 - auc_roc: 0.9498 - pr_auc: 0.3830 - binary_accuracy: 0.9803 - precision: 0.7386 - recall: 0.7757 - val_loss: 2.2186 - val_auc_roc: 0.9098 - val_pr_auc: 0.3193 - val_binary_accuracy: 0.9763 - val_precision: 0.6913 - val_recall: 0.7140 - val_f1_macro: 0.2743 - lr: 7.5000e-05
# Epoch 33/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.4427 - auc_roc: 0.9484 - pr_auc: 0.3848 - binary_accuracy: 0.9806 - precision: 0.7426 - recall: 0.7779  — val_f1_macro: 0.2867
#
# Epoch 33: val_f1_macro improved from 0.28044 to 0.28672, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 108s 198ms/step - loss: 1.4425 - auc_roc: 0.9484 - pr_auc: 0.3848 - binary_accuracy: 0.9806 - precision: 0.7426 - recall: 0.7780 - val_loss: 2.2451 - val_auc_roc: 0.9118 - val_pr_auc: 0.3213 - val_binary_accuracy: 0.9769 - val_precision: 0.7018 - val_recall: 0.7140 - val_f1_macro: 0.2867 - lr: 7.5000e-05
# Epoch 34/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.4376 - auc_roc: 0.9513 - pr_auc: 0.3886 - binary_accuracy: 0.9806 - precision: 0.7436 - recall: 0.7781  — val_f1_macro: 0.2821
#
# Epoch 34: val_f1_macro did not improve from 0.28672
# 545/545 [==============================] - 89s 162ms/step - loss: 1.4374 - auc_roc: 0.9513 - pr_auc: 0.3885 - binary_accuracy: 0.9806 - precision: 0.7436 - recall: 0.7781 - val_loss: 2.2380 - val_auc_roc: 0.9103 - val_pr_auc: 0.3255 - val_binary_accuracy: 0.9762 - val_precision: 0.6907 - val_recall: 0.7150 - val_f1_macro: 0.2821 - lr: 7.5000e-05
# Epoch 35/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4503 - auc_roc: 0.9500 - pr_auc: 0.3855 - binary_accuracy: 0.9805 - precision: 0.7425 - recall: 0.7765  — val_f1_macro: 0.2791
#
# Epoch 35: val_f1_macro did not improve from 0.28672
# 545/545 [==============================] - 76s 139ms/step - loss: 1.4503 - auc_roc: 0.9500 - pr_auc: 0.3855 - binary_accuracy: 0.9805 - precision: 0.7425 - recall: 0.7765 - val_loss: 2.1469 - val_auc_roc: 0.9116 - val_pr_auc: 0.3294 - val_binary_accuracy: 0.9765 - val_precision: 0.6943 - val_recall: 0.7186 - val_f1_macro: 0.2791 - lr: 7.5000e-05
# Epoch 36/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4212 - auc_roc: 0.9526 - pr_auc: 0.3915 - binary_accuracy: 0.9808 - precision: 0.7453 - recall: 0.7799  — val_f1_macro: 0.2813
#
# Epoch 36: val_f1_macro did not improve from 0.28672
# 545/545 [==============================] - 86s 158ms/step - loss: 1.4212 - auc_roc: 0.9526 - pr_auc: 0.3915 - binary_accuracy: 0.9808 - precision: 0.7453 - recall: 0.7799 - val_loss: 2.3627 - val_auc_roc: 0.9080 - val_pr_auc: 0.3189 - val_binary_accuracy: 0.9754 - val_precision: 0.6747 - val_recall: 0.7194 - val_f1_macro: 0.2813 - lr: 7.5000e-05
# Epoch 37/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4276 - auc_roc: 0.9517 - pr_auc: 0.3895 - binary_accuracy: 0.9810 - precision: 0.7491 - recall: 0.7802  — val_f1_macro: 0.2858
#
# Epoch 37: val_f1_macro did not improve from 0.28672
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 545/545 [==============================] - 87s 159ms/step - loss: 1.4276 - auc_roc: 0.9517 - pr_auc: 0.3895 - binary_accuracy: 0.9810 - precision: 0.7491 - recall: 0.7802 - val_loss: 2.3176 - val_auc_roc: 0.9081 - val_pr_auc: 0.3181 - val_binary_accuracy: 0.9769 - val_precision: 0.7022 - val_recall: 0.7140 - val_f1_macro: 0.2858 - lr: 7.5000e-05
# Epoch 38/100
# 545/545 [==============================] - ETA: 0s - loss: 1.4052 - auc_roc: 0.9514 - pr_auc: 0.3945 - binary_accuracy: 0.9810 - precision: 0.7479 - recall: 0.7836  — val_f1_macro: 0.2851
#
# Epoch 38: val_f1_macro did not improve from 0.28672
# 545/545 [==============================] - 108s 198ms/step - loss: 1.4052 - auc_roc: 0.9514 - pr_auc: 0.3945 - binary_accuracy: 0.9810 - precision: 0.7479 - recall: 0.7836 - val_loss: 2.3051 - val_auc_roc: 0.9057 - val_pr_auc: 0.3208 - val_binary_accuracy: 0.9754 - val_precision: 0.6726 - val_recall: 0.7278 - val_f1_macro: 0.2851 - lr: 3.7500e-05
# Epoch 39/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3870 - auc_roc: 0.9506 - pr_auc: 0.3939 - binary_accuracy: 0.9811 - precision: 0.7477 - recall: 0.7857  — val_f1_macro: 0.2796
#
# Epoch 39: val_f1_macro did not improve from 0.28672
# 545/545 [==============================] - 112s 206ms/step - loss: 1.3870 - auc_roc: 0.9506 - pr_auc: 0.3939 - binary_accuracy: 0.9811 - precision: 0.7477 - recall: 0.7857 - val_loss: 2.3195 - val_auc_roc: 0.9027 - val_pr_auc: 0.3155 - val_binary_accuracy: 0.9757 - val_precision: 0.6815 - val_recall: 0.7165 - val_f1_macro: 0.2796 - lr: 3.7500e-05
# Epoch 40/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3701 - auc_roc: 0.9541 - pr_auc: 0.3997 - binary_accuracy: 0.9813 - precision: 0.7514 - recall: 0.7869  — val_f1_macro: 0.2876
#
# Epoch 40: val_f1_macro improved from 0.28672 to 0.28757, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 113s 207ms/step - loss: 1.3701 - auc_roc: 0.9541 - pr_auc: 0.3997 - binary_accuracy: 0.9813 - precision: 0.7514 - recall: 0.7869 - val_loss: 2.3874 - val_auc_roc: 0.9088 - val_pr_auc: 0.3216 - val_binary_accuracy: 0.9764 - val_precision: 0.6921 - val_recall: 0.7202 - val_f1_macro: 0.2876 - lr: 3.7500e-05
# Epoch 41/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3684 - auc_roc: 0.9545 - pr_auc: 0.3994 - binary_accuracy: 0.9812 - precision: 0.7508 - recall: 0.7859  — val_f1_macro: 0.2906
#
# Epoch 41: val_f1_macro improved from 0.28757 to 0.29062, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 95s 173ms/step - loss: 1.3684 - auc_roc: 0.9545 - pr_auc: 0.3994 - binary_accuracy: 0.9812 - precision: 0.7508 - recall: 0.7859 - val_loss: 2.4960 - val_auc_roc: 0.9105 - val_pr_auc: 0.3184 - val_binary_accuracy: 0.9768 - val_precision: 0.7003 - val_recall: 0.7163 - val_f1_macro: 0.2906 - lr: 3.7500e-05
# Epoch 42/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3683 - auc_roc: 0.9549 - pr_auc: 0.3988 - binary_accuracy: 0.9813 - precision: 0.7513 - recall: 0.7867  — val_f1_macro: 0.2889
#
# Epoch 42: val_f1_macro did not improve from 0.29062
# 545/545 [==============================] - 98s 180ms/step - loss: 1.3683 - auc_roc: 0.9549 - pr_auc: 0.3988 - binary_accuracy: 0.9813 - precision: 0.7513 - recall: 0.7867 - val_loss: 2.4403 - val_auc_roc: 0.9091 - val_pr_auc: 0.3224 - val_binary_accuracy: 0.9764 - val_precision: 0.6925 - val_recall: 0.7193 - val_f1_macro: 0.2889 - lr: 3.7500e-05
# Epoch 43/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3455 - auc_roc: 0.9553 - pr_auc: 0.4008 - binary_accuracy: 0.9814 - precision: 0.7523 - recall: 0.7876  — val_f1_macro: 0.2857
#
# Epoch 43: val_f1_macro did not improve from 0.29062
# 545/545 [==============================] - 114s 209ms/step - loss: 1.3454 - auc_roc: 0.9553 - pr_auc: 0.4008 - binary_accuracy: 0.9814 - precision: 0.7524 - recall: 0.7876 - val_loss: 2.4285 - val_auc_roc: 0.9089 - val_pr_auc: 0.3184 - val_binary_accuracy: 0.9760 - val_precision: 0.6838 - val_recall: 0.7232 - val_f1_macro: 0.2857 - lr: 3.7500e-05
# Epoch 44/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3424 - auc_roc: 0.9549 - pr_auc: 0.4002 - binary_accuracy: 0.9814 - precision: 0.7516 - recall: 0.7907  — val_f1_macro: 0.2915
#
# Epoch 44: val_f1_macro improved from 0.29062 to 0.29146, saving model to d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\ecg_inceptiontime_multimodal_asymmetric_loss_best.weights.h5
# 545/545 [==============================] - 114s 209ms/step - loss: 1.3424 - auc_roc: 0.9549 - pr_auc: 0.4002 - binary_accuracy: 0.9814 - precision: 0.7516 - recall: 0.7907 - val_loss: 2.5063 - val_auc_roc: 0.9062 - val_pr_auc: 0.3188 - val_binary_accuracy: 0.9760 - val_precision: 0.6844 - val_recall: 0.7198 - val_f1_macro: 0.2915 - lr: 3.7500e-05
# Epoch 45/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3445 - auc_roc: 0.9543 - pr_auc: 0.4027 - binary_accuracy: 0.9815 - precision: 0.7528 - recall: 0.7897  — val_f1_macro: 0.2854
#
# Epoch 45: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 113s 208ms/step - loss: 1.3444 - auc_roc: 0.9543 - pr_auc: 0.4027 - binary_accuracy: 0.9815 - precision: 0.7528 - recall: 0.7898 - val_loss: 2.5141 - val_auc_roc: 0.9095 - val_pr_auc: 0.3166 - val_binary_accuracy: 0.9764 - val_precision: 0.6945 - val_recall: 0.7119 - val_f1_macro: 0.2854 - lr: 3.7500e-05
# Epoch 46/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3554 - auc_roc: 0.9542 - pr_auc: 0.3950 - binary_accuracy: 0.9814 - precision: 0.7534 - recall: 0.7862  — val_f1_macro: 0.2829
#
# Epoch 46: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 105s 192ms/step - loss: 1.3559 - auc_roc: 0.9542 - pr_auc: 0.3950 - binary_accuracy: 0.9814 - precision: 0.7535 - recall: 0.7861 - val_loss: 2.5749 - val_auc_roc: 0.9112 - val_pr_auc: 0.3161 - val_binary_accuracy: 0.9765 - val_precision: 0.6961 - val_recall: 0.7145 - val_f1_macro: 0.2829 - lr: 3.7500e-05
# Epoch 47/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3362 - auc_roc: 0.9563 - pr_auc: 0.4052 - binary_accuracy: 0.9815 - precision: 0.7536 - recall: 0.7880  — val_f1_macro: 0.2853
#
# Epoch 47: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 99s 180ms/step - loss: 1.3359 - auc_roc: 0.9563 - pr_auc: 0.4052 - binary_accuracy: 0.9815 - precision: 0.7536 - recall: 0.7881 - val_loss: 2.5943 - val_auc_roc: 0.9104 - val_pr_auc: 0.3171 - val_binary_accuracy: 0.9770 - val_precision: 0.7058 - val_recall: 0.7112 - val_f1_macro: 0.2853 - lr: 3.7500e-05
# Epoch 48/100
# 545/545 [==============================] - ETA: 0s - loss: 1.3332 - auc_roc: 0.9564 - pr_auc: 0.4094 - binary_accuracy: 0.9817 - precision: 0.7567 - recall: 0.7894  — val_f1_macro: 0.2892
#
# Epoch 48: val_f1_macro did not improve from 0.29146
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 545/545 [==============================] - 82s 150ms/step - loss: 1.3332 - auc_roc: 0.9564 - pr_auc: 0.4094 - binary_accuracy: 0.9817 - precision: 0.7567 - recall: 0.7894 - val_loss: 2.5586 - val_auc_roc: 0.9105 - val_pr_auc: 0.3168 - val_binary_accuracy: 0.9769 - val_precision: 0.7019 - val_recall: 0.7145 - val_f1_macro: 0.2892 - lr: 3.7500e-05
# Epoch 49/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3146 - auc_roc: 0.9568 - pr_auc: 0.4065 - binary_accuracy: 0.9818 - precision: 0.7569 - recall: 0.7927  — val_f1_macro: 0.2880
#
# Epoch 49: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 92s 168ms/step - loss: 1.3143 - auc_roc: 0.9568 - pr_auc: 0.4066 - binary_accuracy: 0.9818 - precision: 0.7569 - recall: 0.7927 - val_loss: 2.5740 - val_auc_roc: 0.9089 - val_pr_auc: 0.3190 - val_binary_accuracy: 0.9766 - val_precision: 0.6968 - val_recall: 0.7161 - val_f1_macro: 0.2880 - lr: 1.8750e-05
# Epoch 50/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3059 - auc_roc: 0.9569 - pr_auc: 0.4052 - binary_accuracy: 0.9818 - precision: 0.7560 - recall: 0.7944  — val_f1_macro: 0.2890
#
# Epoch 50: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 104s 191ms/step - loss: 1.3058 - auc_roc: 0.9569 - pr_auc: 0.4051 - binary_accuracy: 0.9818 - precision: 0.7561 - recall: 0.7944 - val_loss: 2.6305 - val_auc_roc: 0.9081 - val_pr_auc: 0.3186 - val_binary_accuracy: 0.9765 - val_precision: 0.6946 - val_recall: 0.7181 - val_f1_macro: 0.2890 - lr: 1.8750e-05
# Epoch 51/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3051 - auc_roc: 0.9564 - pr_auc: 0.3996 - binary_accuracy: 0.9818 - precision: 0.7564 - recall: 0.7948  — val_f1_macro: 0.2898
#
# Epoch 51: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 100s 183ms/step - loss: 1.3050 - auc_roc: 0.9565 - pr_auc: 0.3995 - binary_accuracy: 0.9818 - precision: 0.7564 - recall: 0.7948 - val_loss: 2.6019 - val_auc_roc: 0.9093 - val_pr_auc: 0.3192 - val_binary_accuracy: 0.9767 - val_precision: 0.6974 - val_recall: 0.7179 - val_f1_macro: 0.2898 - lr: 1.8750e-05
# Epoch 52/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.3025 - auc_roc: 0.9572 - pr_auc: 0.4037 - binary_accuracy: 0.9818 - precision: 0.7573 - recall: 0.7949  — val_f1_macro: 0.2868
#
# Epoch 52: val_f1_macro did not improve from 0.29146
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
# 545/545 [==============================] - 101s 185ms/step - loss: 1.3028 - auc_roc: 0.9572 - pr_auc: 0.4032 - binary_accuracy: 0.9818 - precision: 0.7572 - recall: 0.7949 - val_loss: 2.6396 - val_auc_roc: 0.9085 - val_pr_auc: 0.3182 - val_binary_accuracy: 0.9764 - val_precision: 0.6927 - val_recall: 0.7181 - val_f1_macro: 0.2868 - lr: 1.8750e-05
# Epoch 53/100
# 545/545 [==============================] - ETA: 0s - loss: 1.2968 - auc_roc: 0.9576 - pr_auc: 0.4098 - binary_accuracy: 0.9819 - precision: 0.7583 - recall: 0.7950  — val_f1_macro: 0.2892
#
# Epoch 53: val_f1_macro did not improve from 0.29146
# 545/545 [==============================] - 102s 186ms/step - loss: 1.2968 - auc_roc: 0.9576 - pr_auc: 0.4098 - binary_accuracy: 0.9819 - precision: 0.7583 - recall: 0.7950 - val_loss: 2.6769 - val_auc_roc: 0.9099 - val_pr_auc: 0.3200 - val_binary_accuracy: 0.9767 - val_precision: 0.6982 - val_recall: 0.7178 - val_f1_macro: 0.2892 - lr: 9.3750e-06
# Epoch 54/100
# 544/545 [============================>.] - ETA: 0s - loss: 1.2803 - auc_roc: 0.9576 - pr_auc: 0.4111 - binary_accuracy: 0.9819 - precision: 0.7570 - recall: 0.7973  — val_f1_macro: 0.2886
#
# Epoch 54: val_f1_macro did not improve from 0.29146
# Restoring model weights from the end of the best epoch: 44.
# 545/545 [==============================] - 105s 192ms/step - loss: 1.2806 - auc_roc: 0.9577 - pr_auc: 0.4111 - binary_accuracy: 0.9819 - precision: 0.7570 - recall: 0.7973 - val_loss: 2.6822 - val_auc_roc: 0.9091 - val_pr_auc: 0.3173 - val_binary_accuracy: 0.9766 - val_precision: 0.6948 - val_recall: 0.7184 - val_f1_macro: 0.2886 - lr: 9.3750e-06
# Epoch 54: early stopping

# %%
def summarize_history(history):
    history_df = pd.DataFrame(history.history)
    print("Last epoch metrics:")
    print(history_df.tail(1).round(4).to_string(index=False))

    if "val_auc_roc" in history_df.columns:
        best_epoch = int(history_df["val_auc_roc"].idxmax()) + 1

        best_val_auc = float(history_df["val_auc_roc"].max())
        print(f"Best validation AUC epoch: {best_epoch}")
        print(f"Best validation AUC: {best_val_auc:.4f}")

    return history_df


def plot_history(history_df):
    if history_df.empty:
        print("No history to plot.")
        return None

    epochs = range(1, len(history_df) + 1)
    fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

    if "loss" in history_df.columns:
        axes[0].plot(epochs, history_df["loss"], marker="o", label="loss")
    if "val_loss" in history_df.columns:
        axes[0].plot(epochs, history_df["val_loss"], marker="o", label="val_loss")
    axes[0].set_title("Loss")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    if "binary_accuracy" in history_df.columns:
        axes[1].plot(epochs, history_df["binary_accuracy"], marker="o", label="binary_accuracy")
    if "val_binary_accuracy" in history_df.columns:
        axes[1].plot(epochs, history_df["val_binary_accuracy"], marker="o", label="val_binary_accuracy")
    axes[1].set_title("Binary Accuracy")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

# في plot_history
    if "auc_roc" in history_df.columns:
        axes[2].plot(epochs, history_df["auc_roc"], label="auc_roc")
    if "val_auc_roc" in history_df.columns:
        axes[2].plot(epochs, history_df["val_auc_roc"], label="val_auc_roc")
        
    axes[2].set_title("AUC")
    axes[2].set_xlabel("Epoch")
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()
    return fig



def safe_multilabel_auc(y_true, y_score, average):
    y_true = np.array(y_true)
    y_score = np.array(y_score)

    valid_columns = []
    for i in range(y_true.shape[1]):
        positive_count = y_true[:, i].sum()
        if 0 < positive_count < len(y_true):
            valid_columns.append(i)

    if not valid_columns:
        return np.nan

    return float(roc_auc_score(y_true[:, valid_columns], y_score[:, valid_columns], average=average))


def batched_multimodal_predict(model, x_signal, x_csv, batch_size=None):
    """بتقييم الموديل على batches صغيرة لتجنب MemoryError"""
    if batch_size is None:
        batch_size = PREDICT_BATCH_SIZE   # <<< استخدام batch أصغر

    if len(x_signal) != len(x_csv):
        raise ValueError(f"signals/features mismatch -> {len(x_signal)} vs {len(x_csv)}")

    predictions = []
    for start in range(0, len(x_signal), batch_size):
        end = min(start + batch_size, len(x_signal))
        signal_batch = np.array(x_signal[start:end], dtype=np.float32)
        csv_batch = np.array(x_csv[start:end], dtype=np.float32)
        batch_prediction = model([signal_batch, csv_batch], training=False).numpy()
        predictions.append(batch_prediction)

        # تحرير الذاكرة بعد كل batch
        del signal_batch, csv_batch
        gc.collect()

    if not predictions:
        return np.empty((0, model.output_shape[-1]), dtype=np.float32)

    return np.vstack(predictions).astype(np.float32)




def evaluate_multimodal_predictions(y_true, y_score, split_name, threshold=METRIC_THRESHOLD):
    y_true = np.array(y_true, dtype=np.float32)
    y_score = np.array(y_score, dtype=np.float32)
    threshold_array = np.array(threshold, dtype=np.float32)
    y_pred = (y_score >= threshold_array).astype(np.float32)

    return {
        "split": split_name,
        "threshold": float(threshold_array.mean()) if threshold_array.ndim else float(threshold_array),
        "threshold_kind": "per_class" if threshold_array.ndim else "global",
        "binary_accuracy": float((y_pred == y_true).mean()),
        "f1_micro": float(f1_score(y_true, y_pred, average="micro", zero_division=0)),
        "f1_macro": float(f1_score(y_true, y_pred, average="macro", zero_division=0)),
        "f1_weighted": float(f1_score(y_true, y_pred, average="weighted", zero_division=0)),
        "auc_micro": safe_multilabel_auc(y_true, y_score, average="micro"),
        "auc_macro": safe_multilabel_auc(y_true, y_score, average="macro"),
    }


def tune_global_threshold(y_true, y_score, grid=THRESHOLD_SEARCH_GRID, optimize_metric="f1_macro"):
    best_metrics = None
    for threshold in np.array(grid, dtype=np.float32):
        metrics = evaluate_multimodal_predictions(y_true, y_score, "validation", threshold=float(threshold))
        if best_metrics is None or metrics[optimize_metric] > best_metrics[optimize_metric]:
            best_metrics = metrics
    return best_metrics


def tune_per_class_thresholds(y_true, y_score, class_names=None, grid=THRESHOLD_SEARCH_GRID):
    y_true = np.array(y_true, dtype=np.float32)
    y_score = np.array(y_score, dtype=np.float32)
    thresholds = np.full(y_true.shape[1], METRIC_THRESHOLD, dtype=np.float32)
    rows = []

    for idx in range(y_true.shape[1]):
        best_threshold = float(METRIC_THRESHOLD)
        best_f1 = -1.0
        label_true = y_true[:, idx]
        label_score = y_score[:, idx]

        for threshold in np.array(grid, dtype=np.float32):
            label_pred = (label_score >= threshold).astype(np.float32)
            label_f1 = float(f1_score(label_true, label_pred, zero_division=0))
            if label_f1 > best_f1:
                best_f1 = label_f1
                best_threshold = float(threshold)

        thresholds[idx] = best_threshold
        label_name = class_names[idx] if class_names is not None else idx
        rows.append({
            "label": str(label_name),
            "support": int(label_true.sum()),
            "threshold": best_threshold,
            "best_label_f1": best_f1,
        })

    thresholds_df = pd.DataFrame(rows).sort_values(["support", "threshold", "label"], ascending=[False, True, True]).reset_index(drop=True)
    return thresholds, thresholds_df

# %%
history_df = summarize_history(history)
plot_history(history_df)
# Out:
# Last epoch metrics:
#   loss  auc_roc  pr_auc  binary_accuracy  precision  recall  val_loss  val_auc_roc  val_pr_auc  val_binary_accuracy  val_precision  val_recall  val_f1_macro  lr
# 1.2806   0.9577  0.4111           0.9819      0.757  0.7973    2.6822       0.9091      0.3173               0.9766         0.6948      0.7184        0.2886 0.0
# Best validation AUC epoch: 26
# Best validation AUC: 0.9132

# %%
print("=" * 60)
print("🔍 Step 1: Generating predictions on validation set...")
print("=" * 60)
val_score = batched_multimodal_predict(model, X_val_signal, X_val_csv)
gc.collect()

print("\n" + "=" * 60)
print("🔍 Step 2: Evaluating with FIXED threshold (0.5)...")
print("=" * 60)
fixed_metrics = evaluate_multimodal_predictions(y_val, val_score, "validation_fixed_0.5", threshold=METRIC_THRESHOLD)
print(pd.DataFrame([fixed_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 3: Tuning GLOBAL threshold...")
print("=" * 60)
best_global_metrics = tune_global_threshold(y_val, val_score)
best_global_threshold = best_global_metrics["threshold"]
print(f"Best global threshold: {best_global_threshold}")
print(pd.DataFrame([best_global_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 4: Tuning PER-CLASS thresholds...")
print("=" * 60)
per_class_thresholds, thresholds_df = tune_per_class_thresholds(
    y_val, val_score, class_names=mlb.classes_
)
print("\nPer-class thresholds:")
print(thresholds_df.to_string(index=False))

per_class_val_metrics = evaluate_multimodal_predictions(
    y_val, val_score, "validation_per_class", threshold=per_class_thresholds
)
print("\nValidation metrics with per-class thresholds:")
print(pd.DataFrame([per_class_val_metrics]).set_index("split").round(4).to_string())

print("\n" + "=" * 60)
print("🔍 Step 5: Generating predictions on TEST set...")
print("=" * 60)
test_score = batched_multimodal_predict(model, X_test_signal, X_test_csv)
gc.collect()

print("\n" + "=" * 60)
print("📊 Step 6: Final TEST evaluation — comparison")
print("=" * 60)

# مقارنة: threshold ثابت vs global tuned vs per-class
test_fixed = evaluate_multimodal_predictions(y_test, test_score, "test_fixed_0.5", threshold=0.5)
test_global = evaluate_multimodal_predictions(y_test, test_score, f"test_global_{best_global_threshold}", threshold=best_global_threshold)
test_per_class = evaluate_multimodal_predictions(y_test, test_score, "test_per_class", threshold=per_class_thresholds)

comparison_df = pd.DataFrame([test_fixed, test_global, test_per_class]).set_index("split").round(4)
print("\n🏆 Test Results Comparison:")
print(comparison_df.to_string())
print("\n✅ Per-class thresholds should give the BEST F1 scores!")

# حفظ الـ per-class thresholds للاستخدام في الـ production
np.save(BASE_DIR / "per_class_thresholds.npy", per_class_thresholds)
print(f"\n💾 Per-class thresholds saved to: {BASE_DIR / 'per_class_thresholds.npy'}")
# Out:
# ============================================================
# 🔍 Step 1: Generating predictions on validation set...
# ============================================================
#
# ============================================================
# 🔍 Step 2: Evaluating with FIXED threshold (0.5)...
# ============================================================
#                       threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation_fixed_0.5        0.5         global            0.976    0.7017    0.2915       0.6724     0.9698     0.9062
#
# ============================================================
# 🔍 Step 3: Tuning GLOBAL threshold...
# ============================================================
# Best global threshold: 0.4399999976158142
#             threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation       0.44         global           0.9693    0.6663    0.3092       0.6746     0.9698     0.9062
#
# ============================================================
# 🔍 Step 4: Tuning PER-CLASS thresholds...
# ============================================================
#
# Per-class thresholds:
#   label  support  threshold  best_label_f1
#      SR     1670       0.48       0.941545
#    NORM      955       0.58       0.842680
#   ABQRS      322       0.43       0.529801
#     IMI      266       0.50       0.604052
#    ASMI      236       0.61       0.715152
#     LVH      210       0.55       0.534247
#     NDT      182       0.50       0.495192
#    LAFB      163       0.53       0.778409
#    AFIB      151       0.76       0.867550
#    ISC_      125       0.62       0.590717
#     PVC      114       0.50       0.832618
#   IRBBB      112       0.69       0.622010
#    STD_      101       0.52       0.572650
#   VCLVH       87       0.48       0.245614
#   STACH       83       0.53       0.832370
#    1AVB       80       0.52       0.597403
#    IVCD       78       0.43       0.241379
#   SARRH       77       0.43       0.275132
#    NST_       75       0.41       0.246334
#   ISCAL       66       0.46       0.397351
#   SBRAD       64       0.55       0.600000
#   CRBBB       55       0.46       0.809917
#   QWAVE       55       0.46       0.503311
#   CLBBB       54       0.66       0.825688
#    ILMI       47       0.41       0.378378
#    LOWT       44       0.52       0.359551
# LAO/LAE       43       0.39       0.189189
#     NT_       41       0.52       0.465753
#     PAC       40       0.45       0.258824
#     AMI       36       0.41       0.265060
#     LPR       34       0.57       0.707692
#    INVT       30       0.52       0.456140
#    PACE       29       0.37       0.857143
#    ALMI       29       0.50       0.542373
#   ISCIN       21       0.37       0.206897
#   INJAS       21       0.48       0.473684
#     LMI       20       0.44       0.217391
#   LVOLT       19       0.30       0.079096
#   ISCIL       18       0.44       0.347826
#     DIG       18       0.47       0.450000
#    LPFB       18       0.61       0.551724
#   ISCAS       17       0.39       0.242424
#   SVARR       15       0.26       0.074766
#   INJAL       15       0.41       0.228571
#   ISCLA       14       0.30       0.084337
#   LNGQT       12       0.35       0.117647
#     RVH       12       0.41       0.439024
# RAO/RAE       10       0.31       0.138889
#      EL       10       0.41       0.153846
#   ANEUR       10       0.45       0.181818
#    BIGU        8       0.50       0.222222
#   HVOLT        7       0.30       0.060606
#     WPW        7       0.33       0.285714
#   ILBBB        7       0.44       0.363636
#    AFLT        7       0.73       0.833333
#   ISCAN        5       0.30       0.097561
#   IPLMI        5       0.41       0.444444
#    IPMI        4       0.19       0.032258
#    TAB_        4       0.24       0.016949
#    STE_        3       0.16       0.008214
#   SEHYP        3       0.23       0.058824
#   SVTAC        3       0.33       0.222222
#    PSVT        3       0.36       0.222222
#   INJLA        2       0.20       0.052632
#   INJIL        2       0.23       0.054054
#     PMI        2       0.25       0.142857
#   TRIGU        2       0.27       0.173913
#   INJIN        2       0.30       0.250000
#    3AVB        2       0.35       0.500000
#  PRC(S)        1       0.22       0.090909
#    2AVB        1       0.33       0.400000
#
# Validation metrics with per-class thresholds:
#                       threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# validation_per_class      0.428      per_class           0.9648    0.6253    0.3873       0.6996     0.9698     0.9062
#
# ============================================================
# 🔍 Step 5: Generating predictions on TEST set...
# ============================================================
#
# ============================================================
# 📊 Step 6: Final TEST evaluation — comparison
# ============================================================
#
# 🏆 Test Results Comparison:
#                                 threshold threshold_kind  binary_accuracy  f1_micro  f1_macro  f1_weighted  auc_micro  auc_macro
# split
# test_fixed_0.5                      0.500         global           0.9764    0.7060    0.2847       0.6760     0.9707     0.9108
# test_global_0.4399999976158142      0.440         global           0.9694    0.6664    0.3036       0.6735     0.9707     0.9108
# test_per_class                      0.428      per_class           0.9628    0.6041    0.3225       0.6831     0.9707     0.9108
#
# ✅ Per-class thresholds should give the BEST F1 scores!
#
# 💾 Per-class thresholds saved to: d:\AOU-Graduation-Project\BioIntellect\AI\ECG\App\classification\per_class_thresholds.npy
